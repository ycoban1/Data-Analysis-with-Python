# %% [markdown]
# ___
#
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="Rossum"></p>
#
# ___

# %% [markdown]
# <h1><p style="text-align: center;">Pandas Lesson, Session - 3</p><h1>

# %% [markdown]
# # Pandas Series

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Creating a Pandas Series

# %% [markdown]
# pd.Series(data=None, index=None, dtype=None, name=None, copy=False, fastpath=False)
#
# One-dimensional ndarray with axis labels (including time series).

# %%
labels = ['a','b','c']
my_list = [10, 20, 30]
arr = np.array([10, 20, 30])
d = {'a': 10, 'b': 20, 'c': 30} # Bu sözlük formatıdır

# %% [markdown]
# ### **Using Lists**

# %%
pd.Series(labels) #S büyük harf olmalı dikkat et
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
pd.Series(my_list) #numpy dataları satır olarak verirken, pandas sütun olarak verir
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series([10,20,30]) #örnek bir gösterim
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %% [markdown]
# ### **Using NumPy Arrays**

# %%
arr
# Out:
# array([10, 20, 30])

# %%
pd.Series(data=arr, index=labels) #aynı uzunlukta olmalı indeks yazarken. Yani arr ile labels i verdi
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# ### **Using Dictionary**

# %%
d
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# ### Using Scalar Value

# %%
pd.Series(data="Yusuf")
# Out:
# 0    Yusuf
# dtype: object

# %%
pd.Series(data="Yusuf", index=range(1,5)) #1-5 arasında Yusuf oluşturur
# Out:
# 1    Yusuf
# 2    Yusuf
# 3    Yusuf
# 4    Yusuf
# dtype: object

# %% [markdown]
# ### Data in a Series
#
# A pandas Series can hold a variety of object types:

# %% [markdown]
# {} or set()

# %%
set1 = (1,2,3,5)

# %%
pd.Series(set1)
# Out:
# 0    1
# 1    2
# 2    3
# 3    5
# dtype: int64

# %%
pd.Series([set,list,dict]) #bir seri içinde class ları muhafaza eder
# Out:
# 0     <class 'set'>
# 1    <class 'list'>
# 2    <class 'dict'>
# dtype: object

# %%
pd.Series([set,list,dict])[1] #Set içindeki 1. datayı seçer
# Out:
# list

# %%
pd.Series([sum, print, len])
# Out:
# 0      <built-in function sum>
# 1    <built-in function print>
# 2      <built-in function len>
# dtype: object

# %%
pd.Series([sum, print, len])[0]([3,5,7]) #0. indeks işlemini yapar. Yani sum toplar
# Out:
# 15

# %%
mix_data =['Aziz',2,True]

# %%
ser=pd.Series(mix_data)
ser
# Out:
# 0    Aziz
# 1       2
# 2    True
# dtype: object

# %%
ser.dtype
# Out:
# dtype('O')

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
type(ser[2]) #serinin 2. indeksi
# Out:
# bool

# %%
arr = np.array(mix_data)
arr
# Out:
# array(['Aziz', '2', 'True'], dtype='<U4')

# %%
type(arr[2]) #numpy data type ı değiştirirken pandas değiştirmemişti
# Out:
# numpy.str_

# %% [markdown]
# ### Basic Attributes of Series

# %%
ser = pd.Series(np.random.randint(0,100,7))
ser
# Out:
# 0    13
# 1    67
# 2     5
# 3    61
# 4    91
# 5    85
# 6    63
# dtype: int64

# %%
ser.dtype
# Out:
# dtype('int64')

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
len(ser)
# Out:
# 7

# %%
ser.size #len ile size aynı olur. ser.shape de aynı şeyi verir
# Out:
# 7

# %%
ser.ndim #serinin boyutunu verir
# Out:
# 1

# %%
ser.index #Kabaca data hakkında bilgi verir
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
for i in ser.index:
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
ser.keys() #index ile aynı şeyi verir
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
ser.items()

# %%
list(ser.items())
# Out:
# [(0, 13), (1, 67), (2, 5), (3, 61), (4, 91), (5, 85), (6, 63)]

# %%
for index, value in ser.items(): #index sırası gibi,sol kısım. Value ise o index in değeri
  print(f"index: {index}, value: {value}")
# Out:
# index: 0, value: 13
# index: 1, value: 67
# index: 2, value: 5
# index: 3, value: 61
# index: 4, value: 91
# index: 5, value: 85
# index: 6, value: 63

# %%
[i for i in "cbaefdgihj"]
# Out:
# ['c', 'b', 'a', 'e', 'f', 'd', 'g', 'i', 'h', 'j']

# %%
ser = pd.Series(data = np.random.randint(0,25,10), index = [i for i in "cbaefdgihj"])
ser
# Out:
# c    16
# b    15
# a     6
# e     0
# f    16
# d    22
# g     7
# i    22
# h    16
# j    12
# dtype: int64

# %%
ser.head() # datanın ilk 5 satırını getirir. Parantez içine istediğimiz satır sayısını da yazabiliriz.
# Out:
# c    16
# b    15
# a     6
# e     0
# f    16
# dtype: int64

# %%
ser.tail() #bu da datanın son 5 satırını gtirir
# Out:
# d    22
# g     7
# i    22
# h    16
# j    12
# dtype: int64

# %%
ser.sample() #datanın random 1 satırını getirir. Parantez içine istediğimiz kadar random girebiliriz.
# Out:
# a    6
# dtype: int64

# %%
ser.sort_index(ascending=True) #datayı alfabatik sıraya göre sıralar
# Out:
# a     6
# b    15
# c    16
# d    22
# e     0
# f    16
# g     7
# h    16
# i    22
# j    12
# dtype: int64

# %%
ser.sort_values(ascending=False) #datayı alfabetik sıranın tersine göre sıralar
# Out:
# d    22
# i    22
# c    16
# f    16
# h    16
# b    15
# j    12
# g     7
# a     6
# e     0
# dtype: int64

# %%
ser
# Out:
# c    16
# b    15
# a     6
# e     0
# f    16
# d    22
# g     7
# i    22
# h    16
# j    12
# dtype: int64

# %%
ser.isin([3,10]) #listem içerisinde hangileri 3 ve 10. Onları Tue yapar
# Out:
# c    False
# b    False
# a    False
# e    False
# f    False
# d    False
# g    False
# i    False
# h    False
# j    False
# dtype: bool

# %%
pd.Series([i for i in "clarusway"]) #yazdığımız kelimenin harflerinden seri yapar
# Out:
# 0    c
# 1    l
# 2    a
# 3    r
# 4    u
# 5    s
# 6    w
# 7    a
# 8    y
# dtype: object

# %% [markdown]
# ## Indexing Pandas Series
#
# The key to using a Series is understanding its index. Pandas makes use of these index names or numbers by allowing for fast look up of information.
#
# Let's see some examples of how to grab information from a Series. Let us create two sereis, ser1 and ser2:

# %%
ser1 = pd.Series(data=[1,2,3,4],index = ['USA', 'Germany','USSR', 'Japan']) #index ülke olurken value rakam olacak
ser2 = pd.Series([1,2,5,4],index = ['USA', 'Germany','Italy', 'Japan']) #burada ikisinde de data= ifadesi kullanmasak da yine kabul eder.

# %%
ser1
# Out:
# USA        1
# Germany    2
# USSR       3
# Japan      4
# dtype: int64

# %%
ser2
# Out:
# USA        1
# Germany    2
# Italy      5
# Japan      4
# dtype: int64

# %%
ser1.sort_index() #alfabetik sıraya göre listelers
# Out:
# Germany    2
# Japan      4
# USA        1
# USSR       3
# dtype: int64

# %%
ser2.sort_index()
# Out:
# Germany    2
# Italy      5
# Japan      4
# USA        1
# dtype: int64

# %%
ser1[1] #1.satırın value sini çeker
# Out:
# 2

# %%
ser1["Germany"] #Yukardaki ile aynı şekilde olur
# Out:
# 2

# %% [markdown]
# Operations are then also done based off of index:

# %%
ser1 + ser2 #aynı index varsa topluyor, yoksa NaN oluyor
# Out:
# Germany    4.0
# Italy      NaN
# Japan      8.0
# USA        2.0
# USSR       NaN
# dtype: float64

# %%
ser3 = pd.Series(data = ["a", "b", "c", "d"])
ser3
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
ser3[0]
# Out:
# 'a'

# %%
ser3[:2]
# Out:
# 0    a
# 1    b
# dtype: object

# %%
ser3[::-1] #tersten getirmek için
# Out:
# 3    d
# 2    c
# 1    b
# 0    a
# dtype: object

# %% [markdown]
# ### pandas_series[index] | pandas_series[[indices, indices...]]

# %%
panser = pd.Series(data = [121, 200, 150, 99], index = ["terry", "micheal", "orion", "jason"])
panser
# Out:
# terry      121
# micheal    200
# orion      150
# jason       99
# dtype: int64

# %%
panser1 = pd.Series(index = [121, 200, 150, 99], data = ["terry", "micheal", "orion", "jason"])
panser
# Out:
# terry      121
# micheal    200
# orion      150
# jason       99
# dtype: int64

# %%
panser[["terry","orion"]]
# Out:
# terry    121
# orion    150
# dtype: int64

# %%
panser["terry" : "orion"] #Aşağıdaki ile aynı anlama gelir
# Out:
# terry      121
# micheal    200
# orion      150
# dtype: int64

# %%
panser[0:3] #Yukardaki ile aynı anlama gelir
# Out:
# terry      121
# micheal    200
# orion      150
# dtype: int64

# %% [markdown]
# ### Recap for Several Selecting Attributes

# %%
panser
# Out:
# terry      121
# micheal    200
# orion      150
# jason       99
# dtype: int64

# %%
panser.keys()
# Out:
# Index(['terry', 'micheal', 'orion', 'jason'], dtype='object')

# %%
panser.values
# Out:
# array([121, 200, 150,  99])

# %%
panser.items()

# %%
for index, value in panser.items(): #Burada index ve value yerine i ve j de yazabiliriz
  print(index,value)
# Out:
# terry 121
# micheal 200
# orion 150
# jason 99

# %%
"terry" in panser #panser içinde terry var mı diye sorgular. Ama bu sadece index i sorgular
# Out:
# True

# %%
"bob" in panser.index #index yazsak da yazmasak da sadece index i alır
# Out:
# False

# %%
200 in panser.values #values içinde 200 var mı diye sordular
# Out:
# True

# %%
panser.isin([200,150])
# Out:
# terry      False
# micheal     True
# orion       True
# jason      False
# dtype: bool

# %%
panser["terry"] =50 #terry nin value sini 50 yaptık
panser
# Out:
# terry       50
# micheal    200
# orion      150
# jason       99
# dtype: int64

# %%
panser[panser>100]
# Out:
# micheal    200
# orion      150
# dtype: int64

# %%
panser[panser>100]=175
panser
# Out:
# terry       50
# micheal    175
# orion      175
# jason       99
# dtype: int64
