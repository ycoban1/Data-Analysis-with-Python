# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>

# %% [markdown]
# <img src=https://i.ibb.co/wJW61Y2/Used-cars.jpg width="700" height="200">
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">The Capstone Project of Data Analytics Module</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:150%; text-align:center; border-radius:10px 10px;">Car Price Prediction EDA</p>

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Content</p>
#
# * [INTRODUCTION](#0)
# * [IMPORTING LIBRARIES NEEDED IN THIS NOTEBOOK](#1)
# * [PART-01 (DATA CLEANING)](#2)
# * [THE EXAMINATION OF COLUMNS](#3)
# * [THE END OF DATA CLEANING (PART - 01)](#4)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Introduction</p>
#
# <a id="0"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Once you've installed NumPy & Pandas you can import them as a library:
#
# Welcome to "***Car Price Prediction EDA Project***". This is the capstone project of ***Data Analytics*** Module. **Auto Scout** data used for this project, were scraped from the on-line car trading company, Auto Scout, in 2019, contains many features of 9 different car models. In this project, you will have the opportunity to apply many commonly used algorithms for Data Cleaning and Exploratory Data Analysis by using many Python libraries such as Numpy, Pandas, Matplotlib, Seaborn, Scipy.
#
# The project consists of **3 parts:**
# * **``First part``** is related to **``'data cleaning'``**. It deals with Incorrect Headers (Column names), Incorrect Format, Anomalies, Dropping useless columns.
# * **``Second part``** is related to **``'filling data'``**. It deals with Missing Values. Categorical to numeric transformation is done.
# * **``Third part``** is related to **``'handling outliers of data'``** via Visualisation libraries. Some insights are extracted.

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Importing Libraries Needed in This Notebook</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Once you've installed NumPy & Pandas you can import them as a library:

# %%
pip install skimpy --user
# Out:
# Requirement already satisfied: skimpy in /root/.local/lib/python3.7/site-packages (0.0.5)
# Requirement already satisfied: click==7.1.2 in /usr/local/lib/python3.7/dist-packages (from skimpy) (7.1.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.12.1 in /root/.local/lib/python3.7/site-packages (from skimpy) (2.13.3)
# Requirement already satisfied: rich<11.0.0,>=10.9.0 in /root/.local/lib/python3.7/site-packages (from skimpy) (10.16.2)
# Requirement already satisfied: Pygments<3.0.0,>=2.10.0 in /root/.local/lib/python3.7/site-packages (from skimpy) (2.11.2)
# Requirement already satisfied: pandas<2.0.0,>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from skimpy) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas<2.0.0,>=1.3.2->skimpy) (2022.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas<2.0.0,>=1.3.2->skimpy) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas<2.0.0,>=1.3.2->skimpy) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas<2.0.0,>=1.3.2->skimpy) (1.15.0)
# Requirement already satisfied: colorama<0.5.0,>=0.4.0 in /root/.local/lib/python3.7/site-packages (from rich<11.0.0,>=10.9.0->skimpy) (0.4.4)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /root/.local/lib/python3.7/site-packages (from rich<11.0.0,>=10.9.0->skimpy) (0.9.1)
# Requirement already satisfied: typing-extensions<5.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from rich<11.0.0,>=10.9.0->skimpy) (4.1.1)

# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
#from skimpy import clean_columns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

# %matplotlib inline
# %matplotlib notebook

plt.rcParams["figure.figsize"] = (10,6)
# plt.rcParams['figure.dpi'] = 100

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.2f' % x)

pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">PART- 01 (Data Cleaning)</p>
#
# <a id="2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
df = pd.read_json("scout_car.json", lines=True)

# Without lines=True, you will get "ValueError: Trailing data"
# The following image represents the original view of Json file opened by VScode

# %% [markdown]
# As seen in the image, it looks like you're loading a JSON file which has JSON data on each separate line. This means that .json file at hand contains **one JSON object in each line** as per the specification. In these circumstances, the answer to how you read it into a data frame in Pandas is that you have to read it **line by line** using lines=True.
#
# ![JSON_FILE_ERROR](https://i.ibb.co/4j0SJqW/autoscout-json.png)

# %%
df.head(3).T
# Out:
#                                                                                0  \
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A1
# short_description                    Sportback 1.4 TDI S-tronic Xenon Navi Klima
# body_type                                                                 Sedans
# price                                                                      15770
# vat                                                               VAT deductible
# km                                                                     56,013 km
# registration                                                             01/2016
# prev_owner                                                     2 previous owners
# kW                                                                           NaN
# hp                                                                         66 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n2\n
# Next Inspection                            [\n06/2021\n, \n99 g CO2/km (comb)\n]
# Inspection new                                             [\nYes\n, \nEuro 6\n]
# Warranty                                                 [\n, \n, \n4 (Green)\n]
# Full Service                                                            [\n, \n]
# Non-smoking Vehicle                                                     [\n, \n]
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A1, \n]
# Offer Number                                                     [\nLR-062483\n]
# First Registration                                                [\n, 2016, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                          [\nMythosschwarz\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0588/BDF\n]
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,422 cc\n]
# Cylinders                                                                [\n3\n]
# Weight                                                            [\n1,220 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# CO2 Emission                                            [\n99 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                     [Alloy wheels, Catalytic Converter, Voice Cont...
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, Sicherheit:,  , Deaktivierung für Beifahr...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                                1  \
# url                            https://www.autoscout24.com//offers/audi-a1-1-...
# make_model                                                               Audi A1
# short_description                                                 1.8 TFSI sport
# body_type                                                                 Sedans
# price                                                                      14500
# vat                                                             Price negotiable
# km                                                                     80,000 km
# registration                                                             03/2017
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                        141 kW
# Type                                                        [, Used, , Gasoline]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A1, \n]
# Offer Number                                                                 NaN
# First Registration                                                [\n, 2017, \n]
# Body Color                                                         [\n, Red, \n]
# Paint Type                                                                   NaN
# Body Color Original                                                          NaN
# Upholstery                                                     [\nCloth, Grey\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n3\n]
# Nr. of Seats                                                             [\n4\n]
# Model Code                                                        [\n0588/BCY\n]
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,798 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,255 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                          [\n, Gasoline, \n]
# Consumption                    [[5.6 l/100 km (comb)], [7.1 l/100 km (city)],...
# CO2 Emission                                           [\n129 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                     [Alloy wheels, Sport seats, Sport suspension, ...
# \nSafety & Security\n          [ABS, Central door lock, Central door lock wit...
# description                    [\nLangstreckenfahrzeug daher die hohe Kilomet...
# Emission Label                                                   [\n4 (Green)\n]
# Gears                                                                    [\n7\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                                2
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A1
# short_description              Sportback 1.6 TDI S tronic Einparkhilfe plus+m...
# body_type                                                                 Sedans
# price                                                                      14640
# vat                                                               VAT deductible
# km                                                                     83,450 km
# registration                                                             02/2016
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         85 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                        [\n, \n, \n99 g CO2/km (comb)\n]
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A1, \n]
# Offer Number                                                      [\nAM-95365\n]
# First Registration                                                [\n, 2016, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                 [\nmythosschwarz metallic\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n4\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                          [\nfront\n]
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[3.8 l/100 km (comb)], [4.4 l/100 km (city)],...
# CO2 Emission                                            [\n99 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Cruise control, Electrical ...
# \nEntertainment & Media\n                               [MP3, On-board computer]
# \nExtras\n                                         [Alloy wheels, Voice Control]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, Fahrzeug-Nummer: AM-95365,  , Ehem. UPE 2...
# Emission Label                                                   [\n4 (Green)\n]
# Gears                                                                        NaN
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            15919 non-null  object
#  1   make_model                     15919 non-null  object
#  2   short_description              15873 non-null  object
#  3   body_type                      15859 non-null  object
#  4   price                          15919 non-null  int64
#  5   vat                            11406 non-null  object
#  6   km                             15919 non-null  object
#  7   registration                   15919 non-null  object
#  8   prev_owner                     9091 non-null   object
#  9   kW                             0 non-null      float64
#  10  hp                             15919 non-null  object
#  11  Type                           15917 non-null  object
#  12  Previous Owners                9279 non-null   object
#  13  Next Inspection                3535 non-null   object
#  14  Inspection new                 3932 non-null   object
#  15  Warranty                       10499 non-null  object
#  16  Full Service                   8215 non-null   object
#  17  Non-smoking Vehicle            7177 non-null   object
#  18  null                           15919 non-null  object
#  19  Make                           15919 non-null  object
#  20  Model                          15919 non-null  object
#  21  Offer Number                   12744 non-null  object
#  22  First Registration             14322 non-null  object
#  23  Body Color                     15322 non-null  object
#  24  Paint Type                     10147 non-null  object
#  25  Body Color Original            12160 non-null  object
#  26  Upholstery                     12199 non-null  object
#  27  Body                           15859 non-null  object
#  28  Nr. of Doors                   15707 non-null  object
#  29  Nr. of Seats                   14942 non-null  object
#  30  Model Code                     4978 non-null   object
#  31  Gearing Type                   15919 non-null  object
#  32  Displacement                   15423 non-null  object
#  33  Cylinders                      10239 non-null  object
#  34  Weight                         8945 non-null   object
#  35  Drive chain                    9061 non-null   object
#  36  Fuel                           15919 non-null  object
#  37  Consumption                    14013 non-null  object
#  38  CO2 Emission                   14111 non-null  object
#  39  Emission Class                 12898 non-null  object
#  40
# Comfort & Convenience
#         14999 non-null  object
#  41
# Entertainment & Media
#         14545 non-null  object
#  42
# Extras
#                        12957 non-null  object
#  43
# Safety & Security
#             14937 non-null  object
#  44  description                    15919 non-null  object
#  45  Emission Label                 3985 non-null   object
#  46  Gears                          11207 non-null  object
#  47  Country version                7586 non-null   object
#  48  Electricity consumption        137 non-null    object
#  49  Last Service Date              566 non-null    object
#  50  Other Fuel Types               880 non-null    object
#  51  Availability                   635 non-null    object
#  52  Last Timing Belt Service Date  16 non-null     object
#  53  Available from                 272 non-null    object
# dtypes: float64(1), int64(1), object(52)
# memory usage: 6.6+ MB

# %%
df.columns
# Out:
# Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat',
#        'km', 'registration', 'prev_owner', 'kW', 'hp', 'Type',
#        'Previous Owners', 'Next Inspection', 'Inspection new', 'Warranty',
#        'Full Service', 'Non-smoking Vehicle', 'null', 'Make', 'Model',
#        'Offer Number', 'First Registration', 'Body Color', 'Paint Type',
#        'Body Color Original', 'Upholstery', 'Body', 'Nr. of Doors',
#        'Nr. of Seats', 'Model Code', 'Gearing Type', 'Displacement',
#        'Cylinders', 'Weight', 'Drive chain', 'Fuel', 'Consumption',
#        'CO2 Emission', 'Emission Class', '\nComfort & Convenience\n',
#        '\nEntertainment & Media\n', '\nExtras\n', '\nSafety & Security\n',
#        'description', 'Emission Label', 'Gears', 'Country version',
#        'Electricity consumption', 'Last Service Date', 'Other Fuel Types',
#        'Availability', 'Last Timing Belt Service Date', 'Available from'],
#       dtype='object')

# %% [markdown]
# **Let us rectify the** **``Incorrect Headers (Column names)``**

# %% [markdown]
# One way of renaming the columns in a Pandas dataframe is by using the **``rename()``** function. This method is quite useful when we need to rename some selected columns because we need to specify information only for the columns which are to be renamed [Source](https://www.geeksforgeeks.org/how-to-rename-columns-in-pandas-dataframe/).

# %%
# !pip install skimpy

# %%
# # First Method

# from skimpy import clean_columns

# df = clean_columns(df)
# df.head(3)

# %%
# Second Method

# df["Comfort_Convenience"] = df["\nComfort & Convenience\n"]
#df["Entertainment_Media"] = df["\nEntertainment & Media\n"]
#df["Extras"] = df["\nExtras\n"]
#df["Safety_Security"] = df["\nSafety & Security\n"]

# drop_columns = ["\nComfort & Convenience\n", "\nEntertainment & Media\n", "\nExtras\n", "\nSafety & Security\n"]

# df.drop(drop_columns, axis=1, inplace=True)

# %%
#Third Method

df.rename(columns={"\nComfort & Convenience\n": "Comfort_Convenience",
                   "\nEntertainment & Media\n":"Entertainment_Media",
                   "\nExtras\n":"Extras",
                   "\nSafety & Security\n":"Safety_Security"}, inplace=True)

df.head(3)
# Out:
#                                                  url make_model  \
# 0  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 1  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 2  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
#
#                                    short_description body_type  price  \
# 0        Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                                     1.8 TFSI sport    Sedans  14500
# 2  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans  14640
#
#                 vat         km registration         prev_owner  kW      hp  \
# 0    VAT deductible  56,013 km      01/2016  2 previous owners NaN   66 kW
# 1  Price negotiable  80,000 km      03/2017               None NaN  141 kW
# 2    VAT deductible  83,450 km      02/2016   1 previous owner NaN   85 kW
#
#                                       Type Previous Owners  \
# 0  [, Used, , Diesel (Particulate Filter)]           \n2\n
# 1                     [, Used, , Gasoline]             NaN
# 2  [, Used, , Diesel (Particulate Filter)]           \n1\n
#
#                          Next Inspection         Inspection new  \
# 0  [\n06/2021\n, \n99 g CO2/km (comb)\n]  [\nYes\n, \nEuro 6\n]
# 1                                    NaN                    NaN
# 2                                    NaN                    NaN
#
#                            Warranty Full Service Non-smoking Vehicle null  \
# 0           [\n, \n, \n4 (Green)\n]     [\n, \n]            [\n, \n]   []
# 1                               NaN          NaN                 NaN   []
# 2  [\n, \n, \n99 g CO2/km (comb)\n]          NaN                 NaN   []
#
#        Make         Model     Offer Number First Registration  \
# 0  \nAudi\n  [\n, A1, \n]  [\nLR-062483\n]     [\n, 2016, \n]
# 1  \nAudi\n  [\n, A1, \n]              NaN     [\n, 2017, \n]
# 2  \nAudi\n  [\n, A1, \n]   [\nAM-95365\n]     [\n, 2016, \n]
#
#         Body Color      Paint Type           Body Color Original  \
# 0  [\n, Black, \n]  [\nMetallic\n]           [\nMythosschwarz\n]
# 1    [\n, Red, \n]             NaN                           NaN
# 2  [\n, Black, \n]  [\nMetallic\n]  [\nmythosschwarz metallic\n]
#
#            Upholstery              Body Nr. of Doors Nr. of Seats  \
# 0  [\nCloth, Black\n]  [\n, Sedans, \n]      [\n5\n]      [\n5\n]
# 1   [\nCloth, Grey\n]  [\n, Sedans, \n]      [\n3\n]      [\n4\n]
# 2  [\nCloth, Black\n]  [\n, Sedans, \n]      [\n4\n]      [\n4\n]
#
#        Model Code         Gearing Type    Displacement Cylinders  \
# 0  [\n0588/BDF\n]  [\n, Automatic, \n]  [\n1,422 cc\n]   [\n3\n]
# 1  [\n0588/BCY\n]  [\n, Automatic, \n]  [\n1,798 cc\n]   [\n4\n]
# 2             NaN  [\n, Automatic, \n]  [\n1,598 cc\n]       NaN
#
#            Weight  Drive chain                                   Fuel  \
# 0  [\n1,220 kg\n]  [\nfront\n]  [\n, Diesel (Particulate Filter), \n]
# 1  [\n1,255 kg\n]  [\nfront\n]                     [\n, Gasoline, \n]
# 2             NaN  [\nfront\n]  [\n, Diesel (Particulate Filter), \n]
#
#                                          Consumption  \
# 0  [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 1  [[5.6 l/100 km (comb)], [7.1 l/100 km (city)],...
# 2  [[3.8 l/100 km (comb)], [4.4 l/100 km (city)],...
#
#                 CO2 Emission Emission Class  \
# 0   [\n99 g CO2/km (comb)\n]   [\nEuro 6\n]
# 1  [\n129 g CO2/km (comb)\n]   [\nEuro 6\n]
# 2   [\n99 g CO2/km (comb)\n]   [\nEuro 6\n]
#
#                                  Comfort_Convenience  \
# 0  [Air conditioning, Armrest, Automatic climate ...
# 1  [Air conditioning, Automatic climate control, ...
# 2  [Air conditioning, Cruise control, Electrical ...
#
#                                  Entertainment_Media  \
# 0  [Bluetooth, Hands-free equipment, On-board com...
# 1  [Bluetooth, Hands-free equipment, On-board com...
# 2                           [MP3, On-board computer]
#
#                                               Extras  \
# 0  [Alloy wheels, Catalytic Converter, Voice Cont...
# 1  [Alloy wheels, Sport seats, Sport suspension, ...
# 2                      [Alloy wheels, Voice Control]
#
#                                      Safety_Security  \
# 0  [ABS, Central door lock, Daytime running light...
# 1  [ABS, Central door lock, Central door lock wit...
# 2  [ABS, Central door lock, Daytime running light...
#
#                                          description   Emission Label  \
# 0  [\n, Sicherheit:,  , Deaktivierung für Beifahr...              NaN
# 1  [\nLangstreckenfahrzeug daher die hohe Kilomet...  [\n4 (Green)\n]
# 2  [\n, Fahrzeug-Nummer: AM-95365,  , Ehem. UPE 2...  [\n4 (Green)\n]
#
#      Gears Country version Electricity consumption Last Service Date  \
# 0      NaN             NaN                     NaN               NaN
# 1  [\n7\n]             NaN                     NaN               NaN
# 2      NaN             NaN                     NaN               NaN
#
#   Other Fuel Types Availability Last Timing Belt Service Date Available from
# 0              NaN          NaN                           NaN            NaN
# 1              NaN          NaN                           NaN            NaN
# 2              NaN          NaN                           NaN            NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            15919 non-null  object
#  1   make_model                     15919 non-null  object
#  2   short_description              15873 non-null  object
#  3   body_type                      15859 non-null  object
#  4   price                          15919 non-null  int64
#  5   vat                            11406 non-null  object
#  6   km                             15919 non-null  object
#  7   registration                   15919 non-null  object
#  8   prev_owner                     9091 non-null   object
#  9   kW                             0 non-null      float64
#  10  hp                             15919 non-null  object
#  11  Type                           15917 non-null  object
#  12  Previous Owners                9279 non-null   object
#  13  Next Inspection                3535 non-null   object
#  14  Inspection new                 3932 non-null   object
#  15  Warranty                       10499 non-null  object
#  16  Full Service                   8215 non-null   object
#  17  Non-smoking Vehicle            7177 non-null   object
#  18  null                           15919 non-null  object
#  19  Make                           15919 non-null  object
#  20  Model                          15919 non-null  object
#  21  Offer Number                   12744 non-null  object
#  22  First Registration             14322 non-null  object
#  23  Body Color                     15322 non-null  object
#  24  Paint Type                     10147 non-null  object
#  25  Body Color Original            12160 non-null  object
#  26  Upholstery                     12199 non-null  object
#  27  Body                           15859 non-null  object
#  28  Nr. of Doors                   15707 non-null  object
#  29  Nr. of Seats                   14942 non-null  object
#  30  Model Code                     4978 non-null   object
#  31  Gearing Type                   15919 non-null  object
#  32  Displacement                   15423 non-null  object
#  33  Cylinders                      10239 non-null  object
#  34  Weight                         8945 non-null   object
#  35  Drive chain                    9061 non-null   object
#  36  Fuel                           15919 non-null  object
#  37  Consumption                    14013 non-null  object
#  38  CO2 Emission                   14111 non-null  object
#  39  Emission Class                 12898 non-null  object
#  40  Comfort_Convenience            14999 non-null  object
#  41  Entertainment_Media            14545 non-null  object
#  42  Extras                         12957 non-null  object
#  43  Safety_Security                14937 non-null  object
#  44  description                    15919 non-null  object
#  45  Emission Label                 3985 non-null   object
#  46  Gears                          11207 non-null  object
#  47  Country version                7586 non-null   object
#  48  Electricity consumption        137 non-null    object
#  49  Last Service Date              566 non-null    object
#  50  Other Fuel Types               880 non-null    object
#  51  Availability                   635 non-null    object
#  52  Last Timing Belt Service Date  16 non-null     object
#  53  Available from                 272 non-null    object
# dtypes: float64(1), int64(1), object(52)
# memory usage: 6.6+ MB

# %%
df.shape
# Out:
# (15919, 54)

# %%
df.isnull().sum()
# Out:
# url                                  0
# make_model                           0
# short_description                   46
# body_type                           60
# price                                0
# vat                               4513
# km                                   0
# registration                         0
# prev_owner                        6828
# kW                               15919
# hp                                   0
# Type                                 2
# Previous Owners                   6640
# Next Inspection                  12384
# Inspection new                   11987
# Warranty                          5420
# Full Service                      7704
# Non-smoking Vehicle               8742
# null                                 0
# Make                                 0
# Model                                0
# Offer Number                      3175
# First Registration                1597
# Body Color                         597
# Paint Type                        5772
# Body Color Original               3759
# Upholstery                        3720
# Body                                60
# Nr. of Doors                       212
# Nr. of Seats                       977
# Model Code                       10941
# Gearing Type                         0
# Displacement                       496
# Cylinders                         5680
# Weight                            6974
# Drive chain                       6858
# Fuel                                 0
# Consumption                       1906
# CO2 Emission                      1808
# Emission Class                    3021
# Comfort_Convenience                920
# Entertainment_Media               1374
# Extras                            2962
# Safety_Security                    982
# description                          0
# Emission Label                   11934
# Gears                             4712
# Country version                   8333
# Electricity consumption          15782
# Last Service Date                15353
# Other Fuel Types                 15039
# Availability                     15284
# Last Timing Belt Service Date    15903
# Available from                   15647
# dtype: int64

# %%
df.isnull().sum()*100 / df.shape[0]
# Out:
# url                               0.00
# make_model                        0.00
# short_description                 0.29
# body_type                         0.38
# price                             0.00
# vat                              28.35
# km                                0.00
# registration                      0.00
# prev_owner                       42.89
# kW                              100.00
# hp                                0.00
# Type                              0.01
# Previous Owners                  41.71
# Next Inspection                  77.79
# Inspection new                   75.30
# Warranty                         34.05
# Full Service                     48.39
# Non-smoking Vehicle              54.92
# null                              0.00
# Make                              0.00
# Model                             0.00
# Offer Number                     19.94
# First Registration               10.03
# Body Color                        3.75
# Paint Type                       36.26
# Body Color Original              23.61
# Upholstery                       23.37
# Body                              0.38
# Nr. of Doors                      1.33
# Nr. of Seats                      6.14
# Model Code                       68.73
# Gearing Type                      0.00
# Displacement                      3.12
# Cylinders                        35.68
# Weight                           43.81
# Drive chain                      43.08
# Fuel                              0.00
# Consumption                      11.97
# CO2 Emission                     11.36
# Emission Class                   18.98
# Comfort_Convenience               5.78
# Entertainment_Media               8.63
# Extras                           18.61
# Safety_Security                   6.17
# description                       0.00
# Emission Label                   74.97
# Gears                            29.60
# Country version                  52.35
# Electricity consumption          99.14
# Last Service Date                96.44
# Other Fuel Types                 94.47
# Availability                     96.01
# Last Timing Belt Service Date    99.90
# Available from                   98.29
# dtype: float64

# %% [markdown]
# **Droping columns that have missing values more than %90.**

# %%
def df_nans(df, limit):
    missing = df.isnull().sum()*100 / df.shape[0]
    return missing.loc[lambda x : x >= limit]

def column_nans(serial):
    # display percentage of nans in a Series
    return serial.isnull().sum()*100 / serial.shape[0]

# %%
df_nans(df, 90)
# Out:
# kW                              100.00
# Electricity consumption          99.14
# Last Service Date                96.44
# Other Fuel Types                 94.47
# Availability                     96.01
# Last Timing Belt Service Date    99.90
# Available from                   98.29
# dtype: float64

# %%
column_nans(df["Electricity consumption"])
# Out:
# 99.13939317796344

# %%
drop_columns = df_nans(df, 90).index
drop_columns
# Out:
# Index(['kW', 'Electricity consumption', 'Last Service Date',
#        'Other Fuel Types', 'Availability', 'Last Timing Belt Service Date',
#        'Available from'],
#       dtype='object')

# %%
df.drop(drop_columns, axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat',
#        'km', 'registration', 'prev_owner', 'hp', 'Type', 'Previous Owners',
#        'Next Inspection', 'Inspection new', 'Warranty', 'Full Service',
#        'Non-smoking Vehicle', 'null', 'Make', 'Model', 'Offer Number',
#        'First Registration', 'Body Color', 'Paint Type', 'Body Color Original',
#        'Upholstery', 'Body', 'Nr. of Doors', 'Nr. of Seats', 'Model Code',
#        'Gearing Type', 'Displacement', 'Cylinders', 'Weight', 'Drive chain',
#        'Fuel', 'Consumption', 'CO2 Emission', 'Emission Class',
#        'Comfort_Convenience', 'Entertainment_Media', 'Extras',
#        'Safety_Security', 'description', 'Emission Label', 'Gears',
#        'Country version'],
#       dtype='object')

# %%
df.drop("null", axis=1, inplace=True)

# %%
df.head(3)
# Out:
#                                                  url make_model  \
# 0  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 1  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 2  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
#
#                                    short_description body_type  price  \
# 0        Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                                     1.8 TFSI sport    Sedans  14500
# 2  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans  14640
#
#                 vat         km registration         prev_owner      hp  \
# 0    VAT deductible  56,013 km      01/2016  2 previous owners   66 kW
# 1  Price negotiable  80,000 km      03/2017               None  141 kW
# 2    VAT deductible  83,450 km      02/2016   1 previous owner   85 kW
#
#                                       Type Previous Owners  \
# 0  [, Used, , Diesel (Particulate Filter)]           \n2\n
# 1                     [, Used, , Gasoline]             NaN
# 2  [, Used, , Diesel (Particulate Filter)]           \n1\n
#
#                          Next Inspection         Inspection new  \
# 0  [\n06/2021\n, \n99 g CO2/km (comb)\n]  [\nYes\n, \nEuro 6\n]
# 1                                    NaN                    NaN
# 2                                    NaN                    NaN
#
#                            Warranty Full Service Non-smoking Vehicle  \
# 0           [\n, \n, \n4 (Green)\n]     [\n, \n]            [\n, \n]
# 1                               NaN          NaN                 NaN
# 2  [\n, \n, \n99 g CO2/km (comb)\n]          NaN                 NaN
#
#        Make         Model     Offer Number First Registration  \
# 0  \nAudi\n  [\n, A1, \n]  [\nLR-062483\n]     [\n, 2016, \n]
# 1  \nAudi\n  [\n, A1, \n]              NaN     [\n, 2017, \n]
# 2  \nAudi\n  [\n, A1, \n]   [\nAM-95365\n]     [\n, 2016, \n]
#
#         Body Color      Paint Type           Body Color Original  \
# 0  [\n, Black, \n]  [\nMetallic\n]           [\nMythosschwarz\n]
# 1    [\n, Red, \n]             NaN                           NaN
# 2  [\n, Black, \n]  [\nMetallic\n]  [\nmythosschwarz metallic\n]
#
#            Upholstery              Body Nr. of Doors Nr. of Seats  \
# 0  [\nCloth, Black\n]  [\n, Sedans, \n]      [\n5\n]      [\n5\n]
# 1   [\nCloth, Grey\n]  [\n, Sedans, \n]      [\n3\n]      [\n4\n]
# 2  [\nCloth, Black\n]  [\n, Sedans, \n]      [\n4\n]      [\n4\n]
#
#        Model Code         Gearing Type    Displacement Cylinders  \
# 0  [\n0588/BDF\n]  [\n, Automatic, \n]  [\n1,422 cc\n]   [\n3\n]
# 1  [\n0588/BCY\n]  [\n, Automatic, \n]  [\n1,798 cc\n]   [\n4\n]
# 2             NaN  [\n, Automatic, \n]  [\n1,598 cc\n]       NaN
#
#            Weight  Drive chain                                   Fuel  \
# 0  [\n1,220 kg\n]  [\nfront\n]  [\n, Diesel (Particulate Filter), \n]
# 1  [\n1,255 kg\n]  [\nfront\n]                     [\n, Gasoline, \n]
# 2             NaN  [\nfront\n]  [\n, Diesel (Particulate Filter), \n]
#
#                                          Consumption  \
# 0  [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 1  [[5.6 l/100 km (comb)], [7.1 l/100 km (city)],...
# 2  [[3.8 l/100 km (comb)], [4.4 l/100 km (city)],...
#
#                 CO2 Emission Emission Class  \
# 0   [\n99 g CO2/km (comb)\n]   [\nEuro 6\n]
# 1  [\n129 g CO2/km (comb)\n]   [\nEuro 6\n]
# 2   [\n99 g CO2/km (comb)\n]   [\nEuro 6\n]
#
#                                  Comfort_Convenience  \
# 0  [Air conditioning, Armrest, Automatic climate ...
# 1  [Air conditioning, Automatic climate control, ...
# 2  [Air conditioning, Cruise control, Electrical ...
#
#                                  Entertainment_Media  \
# 0  [Bluetooth, Hands-free equipment, On-board com...
# 1  [Bluetooth, Hands-free equipment, On-board com...
# 2                           [MP3, On-board computer]
#
#                                               Extras  \
# 0  [Alloy wheels, Catalytic Converter, Voice Cont...
# 1  [Alloy wheels, Sport seats, Sport suspension, ...
# 2                      [Alloy wheels, Voice Control]
#
#                                      Safety_Security  \
# 0  [ABS, Central door lock, Daytime running light...
# 1  [ABS, Central door lock, Central door lock wit...
# 2  [ABS, Central door lock, Daytime running light...
#
#                                          description   Emission Label  \
# 0  [\n, Sicherheit:,  , Deaktivierung für Beifahr...              NaN
# 1  [\nLangstreckenfahrzeug daher die hohe Kilomet...  [\n4 (Green)\n]
# 2  [\n, Fahrzeug-Nummer: AM-95365,  , Ehem. UPE 2...  [\n4 (Green)\n]
#
#      Gears Country version
# 0      NaN             NaN
# 1  [\n7\n]             NaN
# 2      NaN             NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 46 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   url                  15919 non-null  object
#  1   make_model           15919 non-null  object
#  2   short_description    15873 non-null  object
#  3   body_type            15859 non-null  object
#  4   price                15919 non-null  int64
#  5   vat                  11406 non-null  object
#  6   km                   15919 non-null  object
#  7   registration         15919 non-null  object
#  8   prev_owner           9091 non-null   object
#  9   hp                   15919 non-null  object
#  10  Type                 15917 non-null  object
#  11  Previous Owners      9279 non-null   object
#  12  Next Inspection      3535 non-null   object
#  13  Inspection new       3932 non-null   object
#  14  Warranty             10499 non-null  object
#  15  Full Service         8215 non-null   object
#  16  Non-smoking Vehicle  7177 non-null   object
#  17  Make                 15919 non-null  object
#  18  Model                15919 non-null  object
#  19  Offer Number         12744 non-null  object
#  20  First Registration   14322 non-null  object
#  21  Body Color           15322 non-null  object
#  22  Paint Type           10147 non-null  object
#  23  Body Color Original  12160 non-null  object
#  24  Upholstery           12199 non-null  object
#  25  Body                 15859 non-null  object
#  26  Nr. of Doors         15707 non-null  object
#  27  Nr. of Seats         14942 non-null  object
#  28  Model Code           4978 non-null   object
#  29  Gearing Type         15919 non-null  object
#  30  Displacement         15423 non-null  object
#  31  Cylinders            10239 non-null  object
#  32  Weight               8945 non-null   object
#  33  Drive chain          9061 non-null   object
#  34  Fuel                 15919 non-null  object
#  35  Consumption          14013 non-null  object
#  36  CO2 Emission         14111 non-null  object
#  37  Emission Class       12898 non-null  object
#  38  Comfort_Convenience  14999 non-null  object
#  39  Entertainment_Media  14545 non-null  object
#  40  Extras               12957 non-null  object
#  41  Safety_Security      14937 non-null  object
#  42  description          15919 non-null  object
#  43  Emission Label       3985 non-null   object
#  44  Gears                11207 non-null  object
#  45  Country version      7586 non-null   object
# dtypes: int64(1), object(45)
# memory usage: 2.9+ MB

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">The Examination of Columns</p>
#
# <a id="3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ## Let's examine and clean all the columns/features one by one

# %% [markdown]
# ## url

# %%
df.url.value_counts(dropna=False)
# Out:
# https://www.autoscout24.com//offers/audi-a1-sportback-1-4-tdi-s-tronic-xenon-navi-klima-diesel-black-bdab349a-caa5-41b0-98eb-c1345b84445e                  1
# https://www.autoscout24.com//offers/opel-insignia-bus-inno-2-0-cdti-aut-navi-bi-xe-led-e6-diesel-black-8710b253-dd98-4ed0-9d46-cbad2d79532b                1
# https://www.autoscout24.com//offers/opel-insignia-sport-tourer-opel-sport-tourer-1-6-cdti-136-ch-a-c-diesel-silver-10b7463b-9f56-4348-af35-df3432b2b585    1
# https://www.autoscout24.com//offers/opel-insignia-2-0cdti-st-business-innovation-navi-bt-diesel-black-ba5a3368-dedc-4e51-9127-3976b26e93c2                 1
# https://www.autoscout24.com//offers/opel-insignia-sport-tourer-opel-sport-tourer-1-6-cdti-136-ch-a-c-diesel-silver-7b52f054-78d3-4d5e-9370-8a7d081d7edd    1
#                                                                                                                                                           ..
# https://www.autoscout24.com//offers/audi-a3-sb-30-1-6-tdi-business-116cv-s-tronic-diesel-black-cf50f7b1-4d7b-466f-93a2-4e11ec0b4107                        1
# https://www.autoscout24.com//offers/audi-a3-sb-30-1-6-tdi-business-116cv-s-tronic-diesel-grey-3f47eb34-15c4-4763-860d-78fcbbd2c9ff                         1
# https://www.autoscout24.com//offers/audi-a3-sb-30-1-6-tdi-business-116cv-s-tronic-diesel-silver-f7a4bc95-b2ef-4bac-9497-6bcbcd05db0b                       1
# https://www.autoscout24.com//offers/audi-a3-sb-30-1-6-tdi-business-116cv-s-tronic-diesel-silver-1c94c7a2-67b5-49ca-ae42-42a6800fb3f5                       1
# https://www.autoscout24.com//offers/renault-espace-initiale-paris-tce-225-edc-gpf-navi-shz-aux-gasoline-grey-0bd690d9-7e93-4cab-bc5a-9d5b63402481          1
# Name: url, Length: 15919, dtype: int64

# %%
# A data analyst should primarily benefit from all incoming data s/he encounters; HOWEVER,
# Even if url contains some information, we do NOT need it since this information can be obtained from other features.

df.drop("url", axis=1, inplace=True)

# %% [markdown]
# ## make_model

# %%
df.make_model.value_counts(dropna=False)
# Out:
# Audi A3           3097
# Audi A1           2614
# Opel Insignia     2598
# Opel Astra        2526
# Opel Corsa        2219
# Renault Clio      1839
# Renault Espace     991
# Renault Duster      34
# Audi A2              1
# Name: make_model, dtype: int64

# %% [markdown]
# **As seen, the "make_model" column gives us a more detailed information for our analysis so after the examination of the following columns, "Make" & "Model", we will decide which one/s we will continue.**

# %% [markdown]
# ## Make

# %%
df.Make.value_counts(dropna=False)
# Out:
# \nOpel\n       7343
# \nAudi\n       5712
# \nRenault\n    2864
# Name: Make, dtype: int64

# %%
df["Make"] = df.Make.str.strip('\n')

# %%
df.Make.value_counts(dropna=False)
# Out:
# Opel       7343
# Audi       5712
# Renault    2864
# Name: Make, dtype: int64

# %% [markdown]
# ## Model

# %%
df.Model.value_counts(dropna=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1709, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, A3, \n]          3097
# [\n, A1, \n]          2614
# [\n, Insignia, \n]    2598
# [\n, Astra, \n]       2526
# [\n, Corsa, \n]       2219
# [\n, Clio, \n]        1839
# [\n, Espace, \n]       991
# [\n, Duster, \n]        34
# [\n, A2, \n]             1
# Name: Model, dtype: int64

# %%
df["Model"][0]
# Out:
# ['\n', 'A1', '\n']

# %%
df["Model"][0][1]
# Out:
# 'A1'

# %%
df["Model"].apply(lambda x: x[1])
# Out:
# 0            A1
# 1            A1
# 2            A1
# 3            A1
# 4            A1
#           ...
# 15914    Espace
# 15915    Espace
# 15916    Espace
# 15917    Espace
# 15918    Espace
# Name: Model, Length: 15919, dtype: object

# %%
df.Model.str[1]
# Out:
# 0            A1
# 1            A1
# 2            A1
# 3            A1
# 4            A1
#           ...
# 15914    Espace
# 15915    Espace
# 15916    Espace
# 15917    Espace
# 15918    Espace
# Name: Model, Length: 15919, dtype: object

# %%
df["Model"] = df.Model.str[1]

# %%
df.Model.value_counts(dropna=False)
# Out:
# A3          3097
# A1          2614
# Insignia    2598
# Astra       2526
# Corsa       2219
# Clio        1839
# Espace       991
# Duster        34
# A2             1
# Name: Model, dtype: int64

# %%
df.drop(["Make", "Model"], axis=1, inplace=True)

# %% [markdown]
# **After the examination, we have decided to drop the columns, "Make" & "Model" and kept the column of "make_model.**

# %% [markdown]
# ## short_description

# %%
df.short_description.value_counts(dropna=False)
# Out:
# SPB 1.6 TDI 116 CV S tronic Sport                    64
# NaN                                                  46
# 1.4 66kW (90CV) Selective                            40
# MOVE KLIMA CD USB ALLWETTER BLUETOOTH                38
# SPB 30 TFSI S tronic Admired                         35
#                                                      ..
# 2.0 CDTI Business Innovat. NAVI*KAMERA*               1
# 1.4 TFSI S-tronic ultra SB *S-Line*B&O*               1
# Sportback 30 TFSI S-Tronic LED VirtualCockpit         1
# 1.6CDTI Navi 950 ST/ST Xenon Sitzh Tempo PDC BC       1
# TCe 12V 75 CV 5 P Moschino Zen NUOVE! SUPER PROMO     1
# Name: short_description, Length: 10002, dtype: int64

# %%
df.drop("short_description", axis=1, inplace=True)

# %% [markdown]
# ## description

# %%
df['description']
# Out:
# 0        [\n, Sicherheit:,  , Deaktivierung für Beifahr...
# 1        [\nLangstreckenfahrzeug daher die hohe Kilomet...
# 2        [\n, Fahrzeug-Nummer: AM-95365,  , Ehem. UPE 2...
# 3        [\nAudi A1: , - 1e eigenaar , - Perfecte staat...
# 4        [\n, Technik & Sicherheit:, Xenon plus, Klimaa...
#                                ...
# 15914    [\nVettura visionabile nella sede in Via Roma ...
# 15915    [\nDach: Panorama-Glas-Schiebedach, Lackierung...
# 15916    [\n, Getriebe:,  Automatik, Technik:,  Bordcom...
# 15917    [\nDEK:[2691331], Renault Espace Blue dCi 200C...
# 15918    [\n, Sicherheit Airbags:,  , Seitenairbag,  , ...
# Name: description, Length: 15919, dtype: object

# %%
df['description'].astype('str').value_counts(dropna=False)
# Out:
# []                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            636
# ['\n', '\n']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   30
# ['\nSichern Sie sich diesen Audi A1 1.6 TDI Sport DSG zum Top-Preis inklusive dem', 'AUTOHERO-RUNDUM-SORGLOS-PAKET', ' ', 'Infos:', ' 1.Hand, mindestens 12 Monate gültige HU und AU, unfallfrei, deutsche Ausführung', ' ', 'Highlights', ' ', 'Xenon-Scheinwerfer Plus (Abblend- und Fernlicht)', ' ', 'Sportfahrwerk', ' ', 'BOSE Sound-System', ' ', 'Einparkhilfe hinten', ' ', 'Sitzheizung', 'Komfort', ' ', 'Sportsitze vorn', ' ', 'Start/Stop-Anlage', ' ', 'Leder- Multifunktionslenkrad', ' ', 'Klimaautomatik', ' ', 'verstellbare Lendenwirbelstütze', ' ', 'elektrische Fensterheber vorn', ' ', 'Lenkrad mechanisch verstellbar', ' ', 'Rücksitzlehne geteilt/klappbar', ' ', 'Sitz-Paket', ' ', 'Sitze vorn höhenverstellbar', ' ', 'Mittelarmlehne vorne mit Fach', 'Multimedia', ' ', 'Navigations-Paket', ' ', 'Media -Paket', ' ', 'Connectivity-Paket', ' ', 'Universal-Schnittstelle', ' ', 'Bluetooth', ' ', 'Audi music interface', ' ', 'SD-Karten-Schnittstelle', ' ', 'Mulit-Media-Interface MMI Basic/Radio', ' ', 'Fahrer-Informations-System (FIS)', 'Licht und Sicht', ' ', 'Licht- und Regensensor', ' ', 'Nebelscheinwerfer', ' ', 'Verglasung hinten abgedunkelt', ' ', 'Tagfahrlicht', ' ', 'elektrisch verstell- und anklappbare Außenspiegel', 'Sicherheit', ' ', 'Airbag für Fahrer und Beifahrer', ' ', 'Beifahrerairbag deaktivierbar', ' ', 'Seitenairbags vorn', ' ', 'Kopfairbagsystem', ' ', 'Anti-Blockier-System (ABS)', ' ', 'elektronische Differentialsperre (EDS)', ' ', 'elektronisches Stabilitäts-Programm', ' ', 'Reifen-Reparatur-Kit', ' ', 'Reifenkontroll-Anzeige', ' ', 'Wegfahrsperre', ' ', 'ISOFIX Kindersitzverankerung', 'Weiteres', ' ', 'Dachkantenspoiler', ' ', 'Perleffekt-Lackierung', ' ', 'Leichtmetall 7,5x17 (5-Speichen, V-Design, teilpoliert)', ' ', 'Audi Drive Select', ' Ihr ', 'AUTOHERO-RUNDUM-SORGLOS-PAKET', ' beinhaltet:', 'Kostenlose Lieferung in Ihre Nähe', 'Optische & technische Aufbereitung', 'Mindestens 12 Monate gültige HU und AU', '1-Jahr-Premium-Garantie', 'Zulassung inklusive', '14-Tage-Rückgaberecht', 'Markenunabhängige Inzahlungnahme', 'Individuelle Finanzierungen zu fairen Konditionen', ' ', 'HIER GEHT ES ZUR 360° - ANSICHT DES FAHRZEUGES:', ':', 'https://www.autohero.com/de/audi-a-1/id/c05fa3dd-b2e4-4d58-96a6-13914ca5318a/', ' ', 'Haftungsausschluss', ':', 'Für Angaben vom Verkäufer, des Herstellers oder von Datenbankabfragen übernimmt Autohero keine Haftung. Änderungen, Zwischenverkauf und Irrtümer sind vorbehalten.\n']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               27
# ['\n', 'Sichern Sie sich diesen RENAULT ESPACE 1.6 TCE ENERGY INTENS zum Top-Preis inklusive dem', 'AUTOHERO-RUNDUM-SORGLOS-PAKET', ' ', 'Infos:', ' 2.Hand, mindestens 12 Monate gültige HU und AU, deutsche Ausführung, unfallfrei ', ' ', 'Highlights', ' ', 'Navigationssystem R-Link 2 mit Touchscreen', ' ', 'Einparkhilfe vorn und hinten ', ' ', '18? Lapiaz Leichtmetallfelgen ', ' ', 'Scheinwerfer Full-LED', ' ', 'Sitzheizung vorn ', ' ', 'Rückfahrkamera', ' ', 'Panoramadach ', 'Komfort', ' ', 'Multifunktionslenkrad in Nappa Leder ', ' ', 'Volldigitales Kombisinstrument ', ' ', 'Klimaautomatik 2-Zonen mit autom. Umluft-Control', ' ', 'Geschwindigkeits-Begrenzeranlage und -Regelanlage (Tempomat) ', ' ', 'elektrische Fensterheber mit Einklemmschutz', ' ', 'Frontscheibe (Sun-Protect)', ' ', 'Handschuhfach mit Kühlfunktion ', ' ', 'Lendenwirbelstütze Sitz vorn links ', ' ', 'Parkbremse elektrisch ', ' ', 'Rücksitze als Einzelsitze, klappbar / verschiebbar', ' ', 'Sitze vorn höhenverstellbar', ' ', 'Start/Stop-Anlage ', ' ', 'Sun Plus-Paket ', ' ', 'Sonnenschutzrollo an Seitenscheiben hinten', ' ', 'Zentralverriegelung / Startanlage Handsfree Entry & Drive ', ' ', '3.Sitzreihe mit Einzelsitzen ', 'Multimedia', ' ', 'Radioempfang digital (DAB) ', ' ', 'Freisprecheinrichtung Bluetooth', ' ', '2x USB-/SD- und AUX-Schnittstelle', ' ', 'Audiosystem 3D Sound by Arkamys', ' ', 'Steckdose (12V-Anschluß) 2. und 3. Sitzreihe', 'Licht und Sicht', ' ', 'Licht- und Regensensor ', ' ', 'Innenspiegel mit Abblendautomatik ', ' ', 'Ambiente-Beleuchtung ', ' ', 'Außenspiegel elektrisch verstell- und anklappbar', ' ', 'Coming-Home-Lichtfunktion', ' ', 'Verglasung hinten abgedunkelt', ' ', 'Tagfahrlicht LED ', ' ', 'Visio Plus-Paket', ' ', 'Fernlichtassistent', 'Sicherheit', ' ', 'Airbag für Fahrer und Beifahrer', ' ', 'Beifahrerairbag deaktivierbar ', ' ', 'Seitenairbags vorn ', ' ', 'Kopfairbagsystem', ' ', 'Anti-Blockier-System (ABS)', ' ', 'Bremsassistent', ' ', 'Elektronische Stabilitäts-Programm (ESP) mit Grip-Control', ' ', 'Totwinkel-Assistent', ' ', 'Reifen-Reparaturkit ', ' ', 'Reifendruck-Kontrollsystem ', ' ', 'Safety Plus-Paket ', ' ', 'Abstandswarner', ' ', 'ISOFIX Kindersitzverankerung ', ' ', 'Notbrems-Assistent ', ' ', 'Spurwechsel-Warnsystem', ' ', 'Verkehrszeichenerkennung ', 'Weiteres', ' ', 'City-Paket ', ' Ihr ', 'AUTOHERO-RUNDUM-SORGLOS-PAKET', ' beinhaltet:', 'Kostenlose Lieferung in Ihre Nähe', 'Optische & technische Aufbereitung', 'Mindestens 12 Monate gültige HU und AU', '1-Jahr-Premium-Garantie', 'Zulassung inklusive ', '14-Tage-Rückgaberecht', 'Markenunabhängige Inzahlungnahme ', 'Individuelle Finanzierungen zu fairen Konditionen', ' ', 'HIER GEHT ES ZUR 360° - ANSICHT DES FAHRZEUGES:', ':', 'https://www.autohero.com/de/renault-espace-1-6-tce-energy-intens/id/35475dd0-7a9f-4da5-8fca-e41c1e242092/', ' ', 'Haftungsausschluss', ':', 'Für Angaben vom Verkäufer, des Herstellers oder von Datenbankabfragen übernimmt Autohero keine Haftung. Änderungen, Zwischenverkauf und Irrtümer sind vorbehalten.\n']     27
# ['\nSichern Sie sich diesen RENAULT CLIO 1.2 LIMITED zum Top-Preis inklusive dem', 'AUTOHERO-RUNDUM-SORGLOS-PAKET', ' ', 'Infos:', ' 2.Hand, mindestens 12 Monate gültige HU und AU, deutsche Ausführung, unfallfrei ', ' ', 'Highlights', ' ', 'Audio-Navigationssystem mit Touchscreen-Farbdisplay', 'Komfort', ' ', 'Klimaanlage ', ' ', 'Multifunktionslenkrad in Leder ', ' ', 'Berganfahr-Assistent (HSA)', ' ', 'Fensterheber elektrisch vorn ', ' ', 'Geschwindigkeits-Regelanlage (Tempomat) ', ' ', 'Heckscheibe heizbar ', ' ', 'Sitz vorn links höhenverstellbar', ' ', 'Sitz vorn rechts umklappbar ', ' ', 'Stau-/Ablagefach im Laderaumboden ', ' ', 'Zentralverriegelung mit Fernbedienung ', 'Multimedia', ' ', 'Radio R&GO', ' ', 'Bluetooth Freisprechanlage ', ' ', 'USB-/AUX-Schnittstelle ', ' ', 'Bordcomputer', ' ', 'Licht und Sicht', ' ', 'Tagfahrlicht LED ', ' ', 'Außenspiegel elektrisch verstell- und heizbar', 'Sicherheit', ' ', 'Airbag für Fahrer und Beifahrer', ' ', 'Beifahrerairbag deaktivierbar ', ' ', 'Seitenairbags vorn ', ' ', 'Kopfairbagsystem', ' ', 'Anti-Blockier-System (ABS)', ' ', 'Elektronische Bremskraftverteilung ', ' ', 'Elektronische Stabilitäts-Programm (ESP) ', ' ', 'Reifen-Reparaturkit ', ' ', 'Reifendruck-Kontrollsystem ', ' ', 'Untersteuerungskontrolle (USC) ', ' ', 'ISOFIX Kindersitzverankerung ', 'Weiteres', ' ', 'Dachreling silber ', ' ', 'Look-Paket Chrom (außen) ', ' ', 'Look-Paket Grau (innen) ', ' ', 'R&GO-Paket ', ' ', 'Style-Paket ', ' Ihr ', 'AUTOHERO-RUNDUM-SORGLOS-PAKET', ' beinhaltet:', 'Kostenlose Lieferung in Ihre Nähe', 'Optische & technische Aufbereitung', 'Mindestens 12 Monate gültige HU und AU', '1-Jahr-Premium-Garantie', 'Zulassung inklusive ', '14-Tage-Rückgaberecht', 'Markenunabhängige Inzahlungnahme ', 'Individuelle Finanzierungen zu fairen Konditionen', ' ', 'HIER GEHT ES ZUR 360° - ANSICHT DES FAHRZEUGES:', ':', 'https://www.autohero.com/de/renault-clio-1-2-limited/id/30f99516-8785-47e7-a4a3-6cdac4d8e633/', ' ', 'Haftungsausschluss', ':', 'Für Angaben vom Verkäufer, des Herstellers oder von Datenbankabfragen übernimmt Autohero keine Haftung. Änderungen, Zwischenverkauf und Irrtümer sind vorbehalten.\n']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                27
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# ['\n', 'Highlights:', 'Anschlussgarantie 3 Jahre, max. 100.000 km', 'Technik & Sicherheit:', 'Außenspiegel, beheizbar', 'Scheinwerfer-Reinigungsanlage', 'Xenon plus-Scheinwerfer', 'Xenon plus inklusive Scheinwerfer-Reinigungsanlage', 'Einparkhilfe hinten', 'Klimaautomatik', 'Deaktivierung für Beifahrer-Airbag', 'LED-Heckleuchten', 'Nebelscheinwerfer', 'Fensterheber, elektrisch', 'Wegfahrsperre, elektronisch', '5-Gang-Schaltgetriebe', 'Kopfairbag-System mit Seiten-Airbags vorn', 'Servolenkung', 'Tagfahrlicht', 'Start-Stop-System', 'Kindersitzbefestigung ISOFIX und Top', 'Abgaskonzept, EU6 plus', 'Multimedia:', 'MMI® Navigation', 'MMI Radio', 'Bluetooth-Schnittstelle', 'Audi music interface', 'digitaler Radioempfang', 'Navigationspaket', 'media-Paket', 'Sprachdialogsystem', 'Assistenzsysteme:', 'Geschwindigkeitsregelanlage', 'Licht-/Regensensor', 'ESC mit elektronischer Quersperre', 'Reifendruck-Kontrollanzeige', 'Interieur:', 'Rücksitzanlage 2 + 1', 'Mittelarmlehne vorn', 'Multifunktions-Sportlederlenkrad im 3-Speichen-Design', 'Sitzheizung vorn', 'Fahrerinformationssystem', 'Sportsitze vorn', '2-Wege-Lendenwirbelstütze', 'Stoff Herzklopfen', 'Exterieur:', 'Aluminium-Gussräder im 10-Speichen-Design, Größe 7 J x 16,\xa0mit Reifen 215/45 R 16', 'Farbe Nanograu Metallic', 'Scheiben seitlich und hinten in Waermeschutzverglasung', 'Sonstiges:', 'Innenfarbe: Schwarz', 'LED-Innenlichtpaket', 'Außenspiegel, beheizbar, inklusive beheizbarer Scheibenwaschdüsen', 'Außenlackierungen mit Dachkuppel in Kontrastfarbe', '8 Passivlautsprecher, Gesamtleistung 80 Watt', 'Frontscheibe mit grauem Colorstreifen am oberen Rand', 'Funkfernbedienung', 'Tether für die äußeren Fondsitze', 'Dachhimmel in Stoff titangrau', 'Kraftstoffsystem Turbodiesel', 'Abgasendrohre mit Blende in', 'Hochglanzoptik', 'Frontantrieb', 'Ausströmermanschetten Hochglanz schwarz', 'Sportback', '3-Zylinder-Dieselmotor 1,4 L/66 KW TDI Common-Rail Grundmotor ist: T0H/T7M', 'Nichtraucherausführung', 'Reifen 215/45 R 16', 'Dieselpartikelfilter', 'Garantie 60 Monate ab Tag der Erstzulassung', 'Zwischenverkauf und Irrtümer für dieses Angebot sind ausdrücklich vorbehalten. Ausschlaggebend sind einzig und allein die Vereinbarungen in der Auftragsbestätigung oder im Kaufvertrag. Den genauen Ausstattungsumfang erhalten Sie von unserem Verkaufspersonal. Bitte kontaktieren Sie uns.\n']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# ['\n', 'Fahrzeugbeschreibung', 'STANDORT: ', 'Autohaus Berghorn GmbH', 'Hauptstraße 15 ', '31592 Stolzenau, OT Nendorf', 'Tel. 05765 - 9600-0', 'OPEL INSIGNIA ST INNOVATION', '1,6i 125 KW (170 PS)', 'Außenfarbe: Diamant Blau', 'Innenausstattung: Stoff, Ledernachbildung Moroccana', 'Ausstattungslinie: Innovation', 'Abgasnorm Euro 6', 'Listenneupreis ab Standort ca. 41.900,- €', 'Finanzierung und Inzahlungnahme möglich', 'Highlights', 'Frontkamera', 'LM-Felgen 8x18 (5-Doppelspeichen, Rotor-Design)', 'Parkpilotsystem', 'Rückfahrkamera', 'Schließ-/Startsystem Keyless Open', 'Wärmeschutzverglasung hinten abgedunkelt (Solar-Protect)', 'Ausstattung', 'Airbag Beifahrerseite abschaltbar', 'Airbag Fahrer-/Beifahrerseite', 'Aktive Kopfstützen vorn', 'Anti-Blockier-System (ABS)', 'Antriebsart: Frontantrieb', 'Audio-Navigationssystem Navi 900 Touch (IntelliLink 8"-Display)', 'Audiobedienung am Lenkrad', 'Außenspiegel anklappbar und elektr. verstell- und heizbar', 'Außenspiegel Wagenfarbe', 'Ausstiegsleuchten', 'Bi-Xenon-Scheinwerfer mit adaptiver Lichtverteilung (AFL)', 'Bordcomputer', 'Bremsassistent', 'Dachreling silber', 'Drehzahlmesser', 'ecoFLEX-Paket', 'Elektron. Stabilitäts-Programm (ESP)', 'Elektron. Traktionskontrolle', 'Fensterheber elektrisch vorn + hinten', 'Fensterzierleisten Edelstahl / Chrom', 'Gepäckabdeckung / Rollo ausziehbar', 'Geschwindigkeits-Regelanlage (Tempomat)', 'Getriebe 6-Gang', 'Getränkehalter', 'Heckscheibenwischer', 'Isofix-Aufnahmen für Kindersitz an Rücksitz', 'Karosserie: 5-türig', 'Klimaautomatik 2-Zonen', 'Komfortsitze vorn', 'Kopf-Airbag-System', 'Lenkrad (Leder)', 'Lenksäule (Lenkrad) verstellbar', 'Leseleuchten im Fond', 'Leseleuchten vorn (2)', 'LM-Felgen', 'Mittelarmlehne vorn', 'Motor 1,6 Ltr. - 125 kW (170 PS)', 'OnStar SOS Service', 'Reifen-Reparaturkit', 'Reifendruck-Kontrollsystem', 'Rücksitz geteilt / klappbar', 'Schadstoffarm nach Abgasnorm Euro 6', 'Scheibenwischer mit Regensensor', 'Seitenairbag vorn', 'Servolenkung', 'Sicht-Paket', 'Sitzbezug / Polsterung: Stoff / Ledernachbildung', 'Sonnenblenden mit Spiegel (beleuchtet)', 'Start/Stop-Anlage', 'Tagfahrlicht LED', 'Türgriffe innen verchromt', 'Wegfahrsperre', 'Wärmeschutzverglasung', 'Zentralverriegelung mit Fernbedienung', 'Weitere Extraleistungen nach Wunsch zu Sonderpreisen möglich!', 'Ohne Anspruch auf Vollständigkeit,', 'Irrtümer und Tippfehler vorbehalten.', 'Ihr Wunschfahrzeug nicht dabei? ', 'Sprechen Sie uns an!', 'Auch am Wochenende und an Feiertagen telefonisch ', 'erreichbar unter: ', '05765 / 9600-0', 'Wir freuen uns auf Ihren Besuch!', 'www.autohaus-berghorn.de', '\n']                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# ['\n', 'EU-Neuwagen mit Tageszulassung 30.11.2018', 'Sonderausstattung', ' ', ' ', 'Audi connect (Internetbasierende Dienste)', ' ', 'Audi Drive Select', ' ', 'Außenspiegel elektr. verstell-, heiz- und anklappbar ( Außenspiegel mit Bordsteinautomatik, rechts Scheibenwaschdüsen heizbar )', ' ', 'Einparkhilfe hinten (APS)', ' ', 'Fahrer-Informations-System (FIS)', ' ', 'Geschwindigkeits-Regelanlage (Tempomat)', ' ', 'Glanz-Paket', ' ', 'Komfort-Klimaautomatik 2-Zonen', ' ', 'Lenkrad (Sport/Leder - 3-Speichen) mit Multifunktion und Schaltfunktion', ' ', 'Licht-Paket', ' ', 'LM-Felgen 7x16 (5-Speichen, Stern-Design)', ' ', 'Mittelarmlehne vorn', ' ', 'Multi-Media-Interface MMI Navigation', ' ', 'Progressivlenkung', ' ', 'USB-Schnittstelle für Fondpassagiere', ' ', ' ', 'Serienausstattung', ' ', ' ', '8 Lautsprecher', ' ', 'Adaptives Bremslicht', ' ', 'Airbag Fahrer-/Beifahrerseite', ' ', 'Anti-Blockier-System (ABS)', ' ', 'Antriebs-Schlupfregelung (ASR)', ' ', 'Antriebsart: Frontantrieb', ' ', 'Außenspiegel asphärisch, links', ' ', 'Außenspiegel konvex, rechts', ' ', 'Außenspiegel Wagenfarbe', ' ', 'AUX-IN-Anschluss', ' ', 'Blinkleuchten LED in Außenspiegel integriert', ' ', 'Bremsanlage mit Rekuperationssystem', ' ', 'Bremsassistent', ' ', 'Dachhimmel Stoff', ' ', 'Dachspoiler', ' ', 'Elektron. Differentialsperre (EDS)', ' ', 'Elektron. Stabilitäts-Programm (ESP)', ' ', 'Elektron. Stabilitätskontrolle (ESC)', ' ', 'Fahrassistenz-System: Anfahr-Assistent (hold assist)', ' ', 'Fensterheber elektrisch vorn + hinten', ' ', 'Frontscheibe Akustikglas', ' ', 'Fußmatten Velours', ' ', 'Fzg. ohne Sportfahrwerk', ' ', 'Gepäckraumabdeckung / Rollo', ' ', 'Gepäckraumboden doppelt und herausnehmbar', ' ', 'Getriebe 7-Gang - Doppelkupplungsgetriebe S-tronic', ' ', 'Heckscheibe heizbar', ' ', 'Innenausstattung: Dekoreinlagen Micrometallic silber', ' ', 'Isofix-Aufnahmen für Kindersitz', ' ', 'Karosserie: 4-türig', ' ', 'Knieairbag Beifahrerseite', ' ', 'Knieairbag Fahrerseite', ' ', 'Kopf-Airbag-System (Sideguard)', ' ', 'Kopfstützen hinten (3-fach)', ' ', 'Modellbezeichnung mit neuer Leistungskennzeichnung', ' ', 'Motor 1,6 Ltr. - 85 kW TDI', ' ', 'Multi-Media-Interface MMI Basic Plus / MMI Radio Plus', ' ', 'Nichtraucher-Paket', ' ', 'Parkbremse elektro-mechanisch', ' ', 'Reifen-Reparaturkit', ' ', 'Reifendruck-Kontrollsystem', ' ', 'Rücksitzlehne geteilt/klappbar', ' ', 'Rußpartikelfilter', ' ', 'Schadstoffarm nach Abgasnorm Euro 6d-TEMP', ' ', 'Seitenairbag vorn', ' ', 'Servolenkung elektro-mechanisch', ' ', 'Sitzbezug / Polsterung: Stoff Index', ' ', 'Sitze vorn höhenverstellbar', ' ', 'Start/Stop-Anlage', ' ', 'Uni-Lackierung', ' ', 'Vorrüstung Mobiltelefon/Handy mit Bluetooth-Schnittstelle', ' ', 'Wagenheber', ' ', 'Wärmeschutzverglasung grün getönt', ' ', 'Wegfahrsperre (elektronisch)', ' ', 'Xenon-Scheinwerfer Plus (Abblend- und Fernlicht)', ' ', 'Zentralverriegelung mit Fernbedienung', ' ', '\n']                                                                                                                   1
# ['\nMarque: AUDIModèle: A3 SPORTBACKVersion: 1.6 TDI 116ch Design S tronic 7Energie: DieselAnnée: 2017Couleur: NOIRECarroserie: CitadineBoite: AutomatiquePortes: 5Places: 5Cylindrée: 1598Garantie: Garantie OR 12 moisEquipements: ABS, Accoudoir central AV, Airbag conducteur, Airbag genoux, Airbag passager déconnectable, Airbags latéraux avant, Airbags rideaux, Antipatinage, Arrêt et redémarrage auto. du moteur, BAS, Boite à gants fermée, Buses de lave-glace chauffantes, Capteur de luminosité, Capteur de pluie, Ceinture de vitrage chromée, Clim automatique bi-zones, Commandes du système audio au volant, Compte tours, Contrôle élect. de la pression des pneus, EBD, Ecran multifonction couleur, ESP, Feux de jour à LED, Filtre à particules, Filtre à Pollen, Fixation Isofix siège passager avant, Fixations Isofix aux places arrières, Fonction MP3, Interface Media, Jantes Alu, Kit mains-libres Bluetooth, Lecteur carte SD, Lecteur CD, Miroir de courtoisie conducteur éclairé, Miroir de courtoisie passager éclairé, Ordinateur de bord, Palettes changement vitesses au volant, Pare-brise acoustique, Phares xénon, Prise auxiliaire de connexion audio, Prise iPod, Prise USB, Radar de stationnement AR, Radio, Régulateur de vitesse, Répartiteur électronique de freinage, Répétiteurs de clignotant dans rétro ext, Rétroviseur intérieur électrochrome, Rétroviseurs dégivrants, Rétroviseurs électriques, Rétroviseurs ext. indexés à la marche AR, Rétroviseurs rabattables électriquement, Services connectés, Siège conducteur réglable en hauteur, Vitres arrière électriques, Vitres avant électriques, Volant cuir, Volant multifonction, Volant réglable en profondeur et hauteur\n']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# ['\n', 'Ausstattungspakete:', ' Winterpaket', 'Assistenzsysteme:', ' Totwinkel-Assistent, Spurhalteassistent, Abstandstempomat, Kollisionswarnung, Geschwindigkeitsbegrenzer', 'Licht und Sicht:', ' LED-Scheinwerfer, LED-Tagfahrlicht, Automatisch abblendender Innenspiegel, Colorverglasung, Ambientebeleuchtung, beheizbare Frontscheibe', 'Audio & Kommunikation:', ' Radio-Navigationssystem: R-Link 2 mit Touchscreen-Farbdisplay, Multi-Funktions-Display, Digitaler Radioempfang DAB, AUX & USB Anschluss, Touchscreen Bedienung', 'Räder und Reifen:', ' Reifenpannenset', 'Komfort:', ' Klimaautomatik, 2 Zonen, Panoramadach, Fahrer-/Beifahrersitz elektrisch, Memoryfunktion Fahrersitz, Lordosenstütze Fahrer, Sitzheizung vorn u. hinten, Servotronic, Lenksäule verstellbar, Handsfree Entry & Drive, Automatisch öffnende Heckklappe', 'Interieur:', ' Sitze Leder, 7-Sitzer / 3. Sitzreihe: mit Einzelsitzen, Lederlenkrad: Leder Nappa 3-Speichen, Lenkradheizung, Rücksitze klapp- und teilbar', 'Exterieur:', ' Elektronische Dämpfer Control EDC, Außenspiegel elekt. anklappbar, Start-Stopp System', 'Sicherheit:', ' 10 x Airbag, Antriebsschlupfregelung ASR, Bremsassistent, Reifendruckverlust-Warnung', 'Weiteres:', ' Audiosystem 3D Sound by Arkamys, Touchscreen (8,7 Zoll), Fahrassistenz-System: Multi-Sense (Fahrmodusschalter), Multi-Sense 4Control-Paket, Allradlenkung, Cruising-Paket, Parkbremse elektrisch, Visio Plus-Paket, Safety Plus-Paket, Sun Plus-Paket, Sonnenschutzrollo für Seitenscheiben, Steckdose (12V-Anschluß) 2.Sitzreihe, Modelljahr 2017, CO2-Effizienzklasse: A', 'Weiteres: Irrtümer und Änderungen vorbehalten', '\n']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       1
# Name: description, Length: 12874, dtype: int64

# %%
df.drop("description", axis=1, inplace=True)

# %% [markdown]
# **Even if the columns of "short_description" & "description" contain detailed information, we do NOT need it since this information can be obtained from other features.**

# %% [markdown]
# ## body_type

# %%
df.body_type.value_counts(dropna=False)
# Out:
# Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# Other             290
# Transporter        88
# NaN                60
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64

# %% [markdown]
# ## Body

# %%
df.Body.astype('str').value_counts(dropna=False)
# Out:
# ['\n', 'Sedans', '\n']           7903
# ['\n', 'Station wagon', '\n']    3553
# ['\n', 'Compact', '\n']          3153
# ['\n', 'Van', '\n']               783
# ['\n', 'Other', '\n']             290
# ['\n', 'Transporter', '\n']        88
# nan                                60
# ['\n', 'Off-Road', '\n']           56
# ['\n', 'Coupe', '\n']              25
# ['\n', 'Convertible', '\n']         8
# Name: Body, dtype: int64

# %%
df.drop("Body", axis = 1, inplace = True)

# %% [markdown]
# **Both the columns of "body_type" & "Body" have the same information, we will keep the "body_type" column which is more readable.**

# %% [markdown]
# ## price (target column)

# %%
df.price.value_counts(dropna=False)
# Out:
# 14990    154
# 15990    151
# 10990    139
# 15900    106
# 17990    102
#         ...
# 48490      1
# 36180      1
# 40745      1
# 9545       1
# 34815      1
# Name: price, Length: 2956, dtype: int64

# %%
df.price.isnull().sum()
# Out:
# 0

# %%
sns.boxplot(df.price);

# %%
sns.distplot(df.price);

# %% [markdown]
# ## vat
# The **``"Value Added Tax"``** (VAT) in the European Union is a general, broadly based consumption tax assessed on the value added to goods and services.

# %%
df.vat.value_counts(dropna=False)
# Out:
# VAT deductible      10980
# NaN                  4513
# Price negotiable      426
# Name: vat, dtype: int64

# %% [markdown]
# ## km

# %%
df.km.value_counts(dropna=False)
# Out:
# 10 km         1045
# - km          1024
# 1 km           367
# 5 km           170
# 50 km          148
#               ...
# 16,130 km        1
# 32,853 km        1
# 157,300 km       1
# 31,852 km        1
# 28,890 km        1
# Name: km, Length: 6690, dtype: int64

# %%
df["km"] = df.km.str.replace(',', '').str.extract('(\d{1,8})').astype('float')  # str.extract('(\d+)')

# %%
# This is another solution

# df["km"] = df.km.str.replace(',', '').str.rstrip(" km").replace('-', np.nan).astype('float')

# %%
df.km.value_counts(dropna=False)
# Out:
# 10.00       1045
# nan         1024
# 1.00         367
# 5.00         170
# 50.00        148
#             ...
# 8329.00        1
# 267.00         1
# 1060.00        1
# 73652.00       1
# 49320.00       1
# Name: km, Length: 6690, dtype: int64

# %% [markdown]
# ## registration & First Registration

# %%
df.registration.value_counts(dropna=False)
# Out:
# -/-        1597
# 03/2018     695
# 02/2019     585
# 05/2018     572
# 03/2019     543
# 04/2018     541
# 01/2019     541
# 02/2018     539
# 03/2016     536
# 06/2018     532
# 04/2016     532
# 01/2018     511
# 04/2019     506
# 02/2016     472
# 03/2017     471
# 05/2016     459
# 06/2016     452
# 05/2019     440
# 06/2017     409
# 05/2017     404
# 07/2018     396
# 04/2017     380
# 01/2016     376
# 02/2017     368
# 01/2017     306
# 08/2018     285
# 06/2019     224
# 07/2017     215
# 11/2017     180
# 07/2016     176
# 10/2016     160
# 10/2017     154
# 09/2017     149
# 11/2016     142
# 09/2016     141
# 09/2018     141
# 12/2016     134
# 12/2017     123
# 08/2017     114
# 11/2018     110
# 12/2018     103
# 10/2018      97
# 08/2016      94
# 07/2019       6
# 09/2019       5
# 08/2019       1
# 11/2019       1
# 12/2019       1
# Name: registration, dtype: int64

# %%
df["First Registration"].astype('str').value_counts(dropna=False)
# Out:
# ['\n', '2018', '\n']    4522
# ['\n', '2016', '\n']    3674
# ['\n', '2017', '\n']    3273
# ['\n', '2019', '\n']    2853
# nan                     1597
# Name: First Registration, dtype: int64

# %% [markdown]
# **We prefer "First Registration" column because I don't need month values.**

# %%
df['First Registration'] = df['First Registration'].str[1].astype('float')

# %%
df["First Registration"].value_counts(dropna=False)
# Out:
# 2018.00    4522
# 2016.00    3674
# 2017.00    3273
# 2019.00    2853
# nan        1597
# Name: First Registration, dtype: int64

# %%
# The data used for this project were scraped in 2019.

df['age'] = 2019 - df['First Registration']

# %%
df.age.value_counts(dropna=False)
# Out:
# 1.00    4522
# 3.00    3674
# 2.00    3273
# 0.00    2853
# nan     1597
# Name: age, dtype: int64

# %%
df.drop(["registration", "First Registration"], axis=1, inplace=True)

# %% [markdown]
# ## prev_owner & Previous Owners

# %%
df.prev_owner.value_counts(dropna=False)
# Out:
# 1 previous owner     8294
# NaN                  6828
# 2 previous owners     778
# 3 previous owners      17
# 4 previous owners       2
# Name: prev_owner, dtype: int64

# %%
df["Previous Owners"].astype('str').value_counts(dropna=False)
# Out:
# \n1\n                                                                                                        8101
# nan                                                                                                          6640
# \n2\n                                                                                                         766
# \n0\n                                                                                                         163
# \n3\n                                                                                                          17
#                                                                                                              ...
# ['\n1\n', '\n', '6.8 l/100 km (comb)', '\n', '8.7 l/100 km (city)', '\n', '5.7 l/100 km (country)', '\n']       1
# ['\n1\n', '\nEuro 6\n']                                                                                         1
# ['\n1\n', '\n', '6 l/100 km (comb)', '\n', '8 l/100 km (city)', '\n', '4.9 l/100 km (country)', '\n']           1
# ['\n1\n', '\n', '5.9 l/100 km (comb)', '\n', '7.6 l/100 km (city)', '\n', '5.1 l/100 km (country)', '\n']       1
# ['\n1\n', '\n104 g CO2/km (comb)\n']                                                                            1
# Name: Previous Owners, Length: 103, dtype: int64

# %% [markdown]
# I prefer "Previous Owners" column because it has less NaN values. But before dropping "prev_owner", I'll fill "Previous Owners" with "prev_owner".

# %%
#[item[0] if type(item) == list else item for item in df["Previous Owners"]]

# %%
# With list comprehension

df["Previous_Owners"] = [item[0] if type(item) == list else item for item in df["Previous Owners"]]
df["Previous_Owners"]
# Out:
# 0        \n2\n
# 1          NaN
# 2        \n1\n
# 3        \n1\n
# 4        \n1\n
#          ...
# 15914      NaN
# 15915    \n1\n
# 15916    \n1\n
# 15917      NaN
# 15918    \n1\n
# Name: Previous_Owners, Length: 15919, dtype: object

# %%
# With apply() function

df["Previous_Owners2"] = df["Previous Owners"].apply(lambda item: item[0] if type(item) == list else item)
df["Previous_Owners2"]
# Out:
# 0        \n2\n
# 1          NaN
# 2        \n1\n
# 3        \n1\n
# 4        \n1\n
#          ...
# 15914      NaN
# 15915    \n1\n
# 15916    \n1\n
# 15917      NaN
# 15918    \n1\n
# Name: Previous_Owners2, Length: 15919, dtype: object

# %%
df["Previous_Owners"] = df["Previous_Owners"].str.strip("\n").astype('float')

# %%
df["Previous_Owners"].value_counts(dropna=False)
# Out:
# 1.00    8294
# nan     6640
# 2.00     778
# 0.00     188
# 3.00      17
# 4.00       2
# Name: Previous_Owners, dtype: int64

# %%
df["prev_owner"] = df["prev_owner"].str.extract("(\d*)").astype('float')

# %%
#Alternative method

#df["prev_owner"] = df["prev_owner"].str.split(" ").str[0].astype('float')

# %%
df["prev_owner"].value_counts(dropna=False)
# Out:
# 1.00    8294
# nan     6828
# 2.00     778
# 3.00      17
# 4.00       2
# Name: prev_owner, dtype: int64

# %%
df["Previous_Owners"].fillna(df["prev_owner"], inplace=True)

# %%
df["Previous_Owners"].value_counts(dropna=False)
# Out:
# 1.00    8294
# nan     6640
# 2.00     778
# 0.00     188
# 3.00      17
# 4.00       2
# Name: Previous_Owners, dtype: int64

# %%
df[(df["Previous_Owners"].isna()) & (df["prev_owner"].notna())]#.value_counts()
# Out:
# Empty DataFrame
# Columns: [make_model, body_type, price, vat, km, prev_owner, hp, Type, Previous Owners, Next Inspection, Inspection new, Warranty, Full Service, Non-smoking Vehicle, Offer Number, Body Color, Paint Type, Body Color Original, Upholstery, Nr. of Doors, Nr. of Seats, Model Code, Gearing Type, Displacement, Cylinders, Weight, Drive chain, Fuel, Consumption, CO2 Emission, Emission Class, Comfort_Convenience, Entertainment_Media, Extras, Safety_Security, Emission Label, Gears, Country version, age, Previous_Owners, Previous_Owners2]
# Index: []

# %%
df.drop(["prev_owner", "Previous Owners", "Previous_Owners2"], axis=1, inplace=True)

# %% [markdown]
# ## hp

# %%
df.hp.value_counts(dropna=False)
# Out:
# 85 kW     2542
# 66 kW     2122
# 81 kW     1402
# 100 kW    1308
# 110 kW    1112
# 70 kW      888
# 125 kW     707
# 51 kW      695
# 55 kW      569
# 118 kW     516
# 92 kW      466
# 121 kW     392
# 147 kW     380
# 77 kW      345
# 56 kW      286
# 54 kW      276
# 103 kW     253
# 87 kW      232
# 165 kW     194
# 88 kW      177
# 60 kW      160
# 162 kW      98
# - kW        88
# 74 kW       81
# 96 kW       72
# 71 kW       59
# 101 kW      47
# 67 kW       40
# 154 kW      39
# 122 kW      35
# 119 kW      30
# 164 kW      27
# 135 kW      24
# 82 kW       22
# 52 kW       22
# 1 kW        20
# 78 kW       20
# 146 kW      18
# 294 kW      18
# 141 kW      16
# 57 kW       10
# 120 kW       8
# 104 kW       8
# 112 kW       7
# 191 kW       7
# 117 kW       6
# 155 kW       6
# 184 kW       5
# 90 kW        4
# 65 kW        4
# 76 kW        4
# 149 kW       3
# 168 kW       3
# 93 kW        3
# 80 kW        3
# 98 kW        3
# 167 kW       2
# 140 kW       2
# 127 kW       2
# 86 kW        2
# 150 kW       2
# 63 kW        2
# 143 kW       2
# 228 kW       2
# 270 kW       2
# 53 kW        2
# 89 kW        2
# 40 kW        2
# 123 kW       1
# 115 kW       1
# 137 kW       1
# 133 kW       1
# 163 kW       1
# 84 kW        1
# 44 kW        1
# 75 kW        1
# 239 kW       1
# 4 kW         1
# 195 kW       1
# 132 kW       1
# 9 kW         1
# Name: hp, dtype: int64

# %%
df["hp_kW"] = df.hp.str.extract('(\d{1,4})').astype('float') # str.extract('(\d+)')

# %%
#Alternative method

#df.replace({"hp" : {" kW" : ""}}, regex = True, inplace = True)
#df["hp_kw"] = pd.to_numeric(df.hp)

# %%
df.hp_kW.value_counts(dropna=False)
# Out:
# 85.00     2542
# 66.00     2122
# 81.00     1402
# 100.00    1308
# 110.00    1112
# 70.00      888
# 125.00     707
# 51.00      695
# 55.00      569
# 118.00     516
# 92.00      466
# 121.00     392
# 147.00     380
# 77.00      345
# 56.00      286
# 54.00      276
# 103.00     253
# 87.00      232
# 165.00     194
# 88.00      177
# 60.00      160
# 162.00      98
# nan         88
# 74.00       81
# 96.00       72
# 71.00       59
# 101.00      47
# 67.00       40
# 154.00      39
# 122.00      35
# 119.00      30
# 164.00      27
# 135.00      24
# 82.00       22
# 52.00       22
# 1.00        20
# 78.00       20
# 294.00      18
# 146.00      18
# 141.00      16
# 57.00       10
# 104.00       8
# 120.00       8
# 112.00       7
# 191.00       7
# 117.00       6
# 155.00       6
# 184.00       5
# 65.00        4
# 90.00        4
# 76.00        4
# 98.00        3
# 168.00       3
# 93.00        3
# 149.00       3
# 80.00        3
# 140.00       2
# 270.00       2
# 86.00        2
# 40.00        2
# 150.00       2
# 89.00        2
# 53.00        2
# 63.00        2
# 143.00       2
# 127.00       2
# 167.00       2
# 228.00       2
# 195.00       1
# 9.00         1
# 123.00       1
# 133.00       1
# 44.00        1
# 163.00       1
# 239.00       1
# 4.00         1
# 75.00        1
# 115.00       1
# 137.00       1
# 132.00       1
# 84.00        1
# Name: hp_kW, dtype: int64

# %%
df.drop('hp', axis=1, inplace=True)

# %% [markdown]
# ## Type

# %%
df.Type.astype('str').value_counts()
# Out:
# ['', 'Used', '', 'Diesel (Particulate Filter)']                                                                                                       3475
# ['', 'Used', '', 'Diesel']                                                                                                                            2516
# ['', 'Used', '', 'Gasoline']                                                                                                                          2367
# ['', 'Used', '', 'Super 95']                                                                                                                          1818
# ['', 'Pre-registered', '', 'Super 95']                                                                                                                 500
#                                                                                                                                                       ...
# ['', 'Used', '', 'Regular/Benzine 91 / Super 95 / Super Plus 98 / Super Plus E10 98 / Super E10 95 / Regular/Benzine E10 91 (Particulate Filter)']       1
# ['', 'Demonstration', '', 'Super 95 / Regular/Benzine 91 (Particulate Filter)']                                                                          1
# ['', 'New', '', 'CNG (Particulate Filter)']                                                                                                              1
# ['', 'Used', '', 'Regular/Benzine 91 / Super 95 / Super Plus 98']                                                                                        1
# ['', 'Demonstration', '', 'Super Plus 98']                                                                                                               1
# Name: Type, Length: 170, dtype: int64

# %%
# df.Type.apply(pd.Series).stack().value_counts()

# %%
# pd.value_counts(np.hstack(df.Type.values))

# %%
# from itertools import chain

# pd.Series(list(chain.from_iterable(i if isinstance(i, list) else [i] for i in df.Type))).value_counts()

# %%
df["Type"] = df.Type.str[1]

# %%
df['Type'].value_counts(dropna=False)
# Out:
# Used              11096
# New                1650
# Pre-registered     1364
# Employee's car     1011
# Demonstration       796
# NaN                   2
# Name: Type, dtype: int64

# %% [markdown]
# ## Next Inspection & Inspection new

# %%
df["Next Inspection"].astype('str').value_counts(dropna=False)
# Out:
# nan                                           12384
# \n04/2022\n                                      62
# \n03/2021\n                                      38
# \n03/2022\n                                      36
# \n06/2021\n                                      34
#                                               ...
# ['\n01/2020\n', '\n102 g CO2/km (comb)\n']        1
# ['\n09/2019\n', '\n106 g CO2/km (comb)\n']        1
# ['\n04/2019\n', '\n96 g CO2/km (comb)\n']         1
# ['\n04/2020\n', '\n135 g CO2/km (comb)\n']        1
# ['\n12/2021\n', '\n145 g CO2/km (comb)\n']        1
# Name: Next Inspection, Length: 1400, dtype: int64

# %%
df["Inspection new"].astype('str').value_counts(dropna=False)
# Out:
# nan                                                                                                            11987
# ['\nYes\n', '\nEuro 6\n']                                                                                        523
# \nYes\n                                                                                                          362
# ['\nYes\n', '\n102 g CO2/km (comb)\n']                                                                           174
# ['\nYes\n', '\n4 (Green)\n']                                                                                     166
#                                                                                                                ...
# ['\nYes\n', '\n', '6 l/100 km (comb)', '\n', '7.6 l/100 km (city)', '\n', '5 l/100 km (country)', '\n']            1
# ['\nYes\n', '\n', '5 l/100 km (comb)', '\n', '5.8 l/100 km (city)', '\n', '4.5 l/100 km (country)', '\n']          1
# ['\nYes\n', '\n', '6 l/100 km (comb)', '\n', '7.5 l/100 km (city)', '\n', '5.2 l/100 km (country)', '\n']          1
# ['\nYes\n', '\n', '6.7 l/100 km (comb)', '\n', '8.6 l/100 km (city)', '\n', '5.6 l/100 km (country)', '\n']        1
# ['\nYes\n', '\n', '4.4 l/100 km (comb)', '\n', '5.5 l/100 km (city)', '\n', '3.8 l/100 km (country)', '\n']        1
# Name: Inspection new, Length: 203, dtype: int64

# %%
df["Inspection_new"] = [item[0] if type(item) == list else item for item in df["Inspection new"]]

df["Inspection_new"] = df["Inspection_new"].str.strip("\n")

# %%
df["Inspection_new"].value_counts(dropna=False)
# Out:
# NaN    11987
# Yes     3932
# Name: Inspection_new, dtype: int64

# %%
df.drop(["Next Inspection", "Inspection new"], axis=1, inplace=True)

# %% [markdown]
# ## Warranty

# %%
df.Warranty.astype('str').value_counts(dropna=False)
# Out:
# nan                                                                                                                  5420
# ['\n', '\n', '\nEuro 6\n']                                                                                           1868
# \n12 months\n                                                                                                        1177
# \n                                                                                                                    979
# \n24 months\n                                                                                                         566
#                                                                                                                      ...
# ['\n24 months\n', '\n', '4.7 l/100 km (comb)', '\n', '5.4 l/100 km (city)', '\n', '4.2 l/100 km (country)', '\n']       1
# ['\n6 months\n', '\n93 g CO2/km (comb)\n']                                                                              1
# ['\n3 months\n', '\n116 g CO2/km (comb)\n']                                                                             1
# ['\n23 months\n', '\n119 g CO2/km (comb)\n']                                                                            1
# ['\n', '\n', '\n45 g CO2/km (comb)\n']                                                                                  1
# Name: Warranty, Length: 516, dtype: int64

# %%
df["Warranty"] = df.Warranty.apply(lambda x : x[0] if type(x)==list else x)

df["Warranty"] = df.Warranty.str.strip("\n").str.extract('(\d{1,2})').astype("float") # str.extract('(\d+)')

# %%
df.Warranty.value_counts(dropna=False)
# Out:
# nan      11066
# 12.00     2594
# 24.00     1118
# 60.00      401
# 36.00      279
# 48.00      149
# 6.00       125
# 72.00       59
# 3.00        33
# 23.00       11
# 18.00       10
# 20.00        7
# 25.00        6
# 2.00         5
# 26.00        4
# 50.00        4
# 16.00        4
# 1.00         3
# 4.00         3
# 34.00        3
# 19.00        3
# 13.00        3
# 11.00        2
# 21.00        2
# 14.00        2
# 17.00        2
# 45.00        2
# 46.00        2
# 9.00         2
# 22.00        2
# 28.00        2
# 56.00        1
# 47.00        1
# 10.00        1
# 8.00         1
# 7.00         1
# 40.00        1
# 33.00        1
# 65.00        1
# 15.00        1
# 30.00        1
# 49.00        1
# Name: Warranty, dtype: int64

# %% [markdown]
# ## Full Service

# %%
df['Full Service'].astype('str').value_counts(dropna=False)
# Out:
# nan                                                                                                             7704
# ['\n', '\n', '\n4 (Green)\n']                                                                                   2235
# ['\n', '\n', '\nEuro 6\n']                                                                                      2097
# ['\n', '\n']                                                                                                    1702
# ['\n', '\n', '\nEuro 6d-TEMP\n']                                                                                 399
#                                                                                                                 ...
# ['\n', '\n', '\n', '6 l/100 km (comb)', '\n', '8 l/100 km (city)', '\n', '4.9 l/100 km (country)', '\n']           1
# ['\n', '\n', '\n', '5.4 l/100 km (comb)', '\n', '7 l/100 km (city)', '\n', '4.5 l/100 km (country)', '\n']         1
# ['\n', '\n', '\n', '5.4 l/100 km (comb)', '\n', '7.3 l/100 km (city)', '\n', '4.2 l/100 km (country)', '\n']       1
# ['\n', '\n', '\n', '4.3 l/100 km (comb)', '\n', '5.2 l/100 km (city)', '\n', '3.9 l/100 km (country)', '\n']       1
# ['\n', '\n', '\n', '5.9 l/100 km (comb)', '\n', '7.6 l/100 km (city)', '\n', '5.1 l/100 km (country)', '\n']       1
# Name: Full Service, Length: 123, dtype: int64

# %%
df.drop("Full Service", axis=1, inplace=True)

# %% [markdown]
# ## Non-smoking Vehicle

# %%
df['Non-smoking Vehicle']
# Out:
# 0                       [\n, \n]
# 1                            NaN
# 2                            NaN
# 3           [\n, \n, \nEuro 6\n]
# 4                       [\n, \n]
#                   ...
# 15914                        NaN
# 15915    [\n, \n, \n4 (Green)\n]
# 15916                   [\n, \n]
# 15917                        NaN
# 15918                        NaN
# Name: Non-smoking Vehicle, Length: 15919, dtype: object

# %%
df['Non-smoking Vehicle'].astype('str').value_counts(dropna=False)
# Out:
# nan                                                                                                             8742
# ['\n', '\n']                                                                                                    3647
# ['\n', '\n', '\n4 (Green)\n']                                                                                   1240
# ['\n', '\n', '\nEuro 6\n']                                                                                      1127
# ['\n', '\n', '\nEuro 6d-TEMP\n']                                                                                 345
# \n                                                                                                                70
# ['\n', '\n', '\n120 g CO2/km (comb)\n']                                                                           63
# ['\n', '\n', '\n85 g CO2/km (comb)\n']                                                                            46
# ['\n', '\n', '\n107 g CO2/km (comb)\n']                                                                           36
# ['\n', '\n', '\n104 g CO2/km (comb)\n']                                                                           36
# ['\n', '\n', '\n153 g CO2/km (comb)\n']                                                                           31
# ['\n', '\n', '\n124 g CO2/km (comb)\n']                                                                           29
# ['\n', '\n', '\n1 (No sticker)\n']                                                                                24
# ['\n', '\n', '\n99 g CO2/km (comb)\n']                                                                            23
# ['\n', '\n', '\n106 g CO2/km (comb)\n']                                                                           20
# ['\n', '\n', '\n97 g CO2/km (comb)\n']                                                                            20
# ['\n', '\n', '\n108 g CO2/km (comb)\n']                                                                           19
# ['\n', '\n', '\n100 g CO2/km (comb)\n']                                                                           18
# ['\n', '\n', '\n113 g CO2/km (comb)\n']                                                                           18
# ['\n', '\n', '\n109 g CO2/km (comb)\n']                                                                           18
# ['\n', '\n', '\n105 g CO2/km (comb)\n']                                                                           18
# ['\n', '\n', '\nEuro 6c\n']                                                                                       17
# ['\n', '\n', '\n98 g CO2/km (comb)\n']                                                                            15
# ['\n', '\n', '\n129 g CO2/km (comb)\n']                                                                           14
# ['\n', '\n', '\n131 g CO2/km (comb)\n']                                                                           13
# ['\n', '\n', '\n133 g CO2/km (comb)\n']                                                                           12
# ['\n', '\n', '\n103 g CO2/km (comb)\n']                                                                           12
# ['\n', '\n', '\n114 g CO2/km (comb)\n']                                                                           12
# ['\n', '\n', '\n116 g CO2/km (comb)\n']                                                                           11
# ['\n', '\n', '\n102 g CO2/km (comb)\n']                                                                           11
# ['\n', '\n', '\n135 g CO2/km (comb)\n']                                                                           11
# ['\n', '\n', '\n143 g CO2/km (comb)\n']                                                                           10
# ['\n', '\n', '\n127 g CO2/km (comb)\n']                                                                           10
# ['\n', '\n', '\nEuro 6d\n']                                                                                        9
# ['\n', '\n', '\n112 g CO2/km (comb)\n']                                                                            9
# ['\n', '\n', '\n92 g CO2/km (comb)\n']                                                                             9
# ['\n', '\n', '\n118 g CO2/km (comb)\n']                                                                            8
# ['\n', '\n', '\n5 (Blue)\n']                                                                                       8
# ['\n', '\n', '\n128 g CO2/km (comb)\n']                                                                            7
# ['\n', '\n', '\n147 g CO2/km (comb)\n']                                                                            7
# ['\n', '\n', '\n139 g CO2/km (comb)\n']                                                                            7
# ['\n', '\n', '\n126 g CO2/km (comb)\n']                                                                            6
# ['\n', '\n', '\n117 g CO2/km (comb)\n']                                                                            6
# ['\n', '\n', '\n140 g CO2/km (comb)\n']                                                                            6
# ['\n', '\n', '\n137 g CO2/km (comb)\n']                                                                            6
# ['\n', '\n', '\n115 g CO2/km (comb)\n']                                                                            5
# ['\n', '\n', '\n130 g CO2/km (comb)\n']                                                                            5
# ['\n', '\n', '\n', '5.2 l/100 km (comb)', '\n', '5.8 l/100 km (city)', '\n', '4.8 l/100 km (country)', '\n']       4
# ['\n', '\n', '\nEuro 5\n']                                                                                         4
# ['\n', '\n', '\n123 g CO2/km (comb)\n']                                                                            4
# ['\n', '\n', '\n151 g CO2/km (comb)\n']                                                                            4
# ['\n', '\n', '\n136 g CO2/km (comb)\n']                                                                            3
# ['\n', '\n', '\n148 g CO2/km (comb)\n']                                                                            3
# ['\n', '\n', '\n119 g CO2/km (comb)\n']                                                                            3
# ['\n', '\n', '\n110 g CO2/km (comb)\n']                                                                            3
# ['\n', '\n', '\n149 g CO2/km (comb)\n']                                                                            3
# ['\n', '\n', '\n95 g CO2/km (comb)\n']                                                                             3
# ['\n', '\n', '\n157 g CO2/km (comb)\n']                                                                            3
# ['\n', '\n', '\n', '5.2 l/100 km (comb)', '\n', '6.4 l/100 km (city)', '\n', '4.4 l/100 km (country)', '\n']       2
# ['\n', '\n', '\n121 g CO2/km (comb)\n']                                                                            2
# ['\n', '\n', '\n138 g CO2/km (comb)\n']                                                                            2
# ['\n', '\n', '\n125 g CO2/km (comb)\n']                                                                            2
# ['\n', '\n', '\n90 g CO2/km (comb)\n']                                                                             2
# ['\n', '\n', '\n166 g CO2/km (comb)\n']                                                                            2
# ['\n', '\n', '\n134 g CO2/km (comb)\n']                                                                            2
# ['\n', '\n', '\n111 g CO2/km (comb)\n']                                                                            2
# ['\n', '\n', '\n142 g CO2/km (comb)\n']                                                                            2
# ['\n', '\n', '\n', '5.7 l/100 km (comb)', '\n', '7.3 l/100 km (city)', '\n', '4.7 l/100 km (country)', '\n']       1
# ['\n', '\n', '\n122 g CO2/km (comb)\n']                                                                            1
# ['\n', '\n', '\n132 g CO2/km (comb)\n']                                                                            1
# ['\n', '\n', '\n', '6.5 l/100 km (comb)', '\n', '8.5 l/100 km (city)', '\n', '5.4 l/100 km (country)', '\n']       1
# ['\n', '\n', '\n101 g CO2/km (comb)\n']                                                                            1
# ['\n', '\n', '\n144 g CO2/km (comb)\n']                                                                            1
# ['\n', '\n', '\n', '5.6 l/100 km (comb)', '\n', '7.3 l/100 km (city)', '\n', '4.7 l/100 km (country)', '\n']       1
# ['\n', '\n', '\n', '6.4 l/100 km (comb)', '\n', '8.1 l/100 km (city)', '\n', '5.4 l/100 km (country)', '\n']       1
# ['\n', '\n', '\n91 g CO2/km (comb)\n']                                                                             1
# ['\n', '\n', '\n152 g CO2/km (comb)\n']                                                                            1
# ['\n', '\n', '\n150 g CO2/km (comb)\n']                                                                            1
# ['\n', '\n', '\n169 g CO2/km (comb)\n']                                                                            1
# ['\n', '\n', '\n82 g CO2/km (comb)\n']                                                                             1
# ['\n', '\n', '\n172 g CO2/km (comb)\n']                                                                            1
# ['\n', '\n', '\n', '6.3 l/100 km (comb)', '\n', '8 l/100 km (city)', '\n', '5.3 l/100 km (country)', '\n']         1
# ['\n', '\n', '\n156 g CO2/km (comb)\n']                                                                            1
# ['\n', '\n', '\n189 g CO2/km (comb)\n']                                                                            1
# ['\n', '\n', '\n146 g CO2/km (comb)\n']                                                                            1
# ['\n', '\n', '\n159 g CO2/km (comb)\n']                                                                            1
# ['\n', '\n', '\n175 g CO2/km (comb)\n']                                                                            1
# ['\n', '\n', '\n', '6.5 l/100 km (comb)', '\n', '7.9 l/100 km (city)', '\n', '5.6 l/100 km (country)', '\n']       1
# ['\n', '\n', '\n158 g CO2/km (comb)\n']                                                                            1
# ['\n', '\n', '\n', '6.2 l/100 km (comb)', '\n', '7.9 l/100 km (city)', '\n', '5.3 l/100 km (country)', '\n']       1
# ['\n', '\n', '\n154 g CO2/km (comb)\n']                                                                            1
# ['\n', '\n', '\n', '1.6 l/100 km (comb)', '\n', '\n', '\n']                                                        1
# ['\n', '\n', '\n', '6.1 l/100 km (comb)', '\n', '7.8 l/100 km (city)', '\n', '5.1 l/100 km (country)', '\n']       1
# ['\n', '\n', '\n161 g CO2/km (comb)\n']                                                                            1
# ['\n', '\n', '\n', '6.1 l/100 km (comb)', '\n', '7.7 l/100 km (city)', '\n', '5.2 l/100 km (country)', '\n']       1
# Name: Non-smoking Vehicle, dtype: int64

# %%
df.drop("Non-smoking Vehicle", axis=1, inplace=True)

# %% [markdown]
# ## Offer Number

# %%
df['Offer Number'].astype('str').value_counts(dropna=False)
# Out:
# nan                       3175
# ['\nJV03654\n']             27
# ['\nAK13780\n']             27
# ['\nUN89904\n']             27
# ['\nXJ38068\n']             27
#                           ...
# ['\nU087_105546982\n']       1
# ['\n368837\n']               1
# ['\n2091992\n']              1
# ['\nNO122\n']                1
# ['\n424642\n']               1
# Name: Offer Number, Length: 11441, dtype: int64

# %%
df.drop("Offer Number", axis=1, inplace=True)

# %% [markdown]
# ## Body Color

# %%
df['Body Color'].astype('str').value_counts(dropna=False)
# Out:
# ['\n', 'Black', '\n']     3745
# ['\n', 'Grey', '\n']      3505
# ['\n', 'White', '\n']     3406
# ['\n', 'Silver', '\n']    1647
# ['\n', 'Blue', '\n']      1431
# ['\n', 'Red', '\n']        957
# nan                        597
# ['\n', 'Brown', '\n']      289
# ['\n', 'Green', '\n']      154
# ['\n', 'Beige', '\n']      108
# ['\n', 'Yellow', '\n']      51
# ['\n', 'Violet', '\n']      18
# ['\n', 'Bronze', '\n']       6
# ['\n', 'Orange', '\n']       3
# ['\n', 'Gold', '\n']         2
# Name: Body Color, dtype: int64

# %%
df.drop("Body Color", axis=1, inplace=True)

# %% [markdown]
# ## Body Color Original

# %%
df['Body Color Original']
# Out:
# 0                 [\nMythosschwarz\n]
# 1                                 NaN
# 2        [\nmythosschwarz metallic\n]
# 3                                 NaN
# 4        [\nMythosschwarz Metallic\n]
#                      ...
# 15914              [\nGrigio scuro\n]
# 15915       [\nStahl-Grau Metallic\n]
# 15916               [\narktis-weiß\n]
# 15917                    [\nGrigio\n]
# 15918    [\nTitanium-Grau Metallic\n]
# Name: Body Color Original, Length: 15919, dtype: object

# %%
df['Body Color Original'].astype('str').value_counts(dropna=False)
# Out:
# nan                                       3759
# ['\nOnyx Schwarz\n']                       338
# ['\nBianco\n']                             282
# ['\nMythosschwarz Metallic\n']             238
# ['\nBrillantschwarz\n']                    216
#                                           ...
# ['\n(weiß) Abalone Weiss\n']                 1
# ['\nFlorettsilber Metallic / Dayto\n']       1
# ['\nOnyx Schwarz metallic\n']                1
# ['\nGris Platine (licht grijs\n']            1
# ['\nanthracite\n']                           1
# Name: Body Color Original, Length: 1928, dtype: int64

# %%
df.drop("Body Color Original", axis=1, inplace=True)

# %% [markdown]
# ## Paint Type

# %%
df['Paint Type'].astype('str').value_counts(dropna=False)
# Out:
# ['\nMetallic\n']       9794
# nan                    5772
# ['\nUni/basic\n']       347
# ['\nPerl effect\n']       6
# Name: Paint Type, dtype: int64

# %%
df['Paint_Type'] = df['Paint Type'].str[0].str.strip('\n')

# %%
df['Paint_Type'].value_counts(dropna=False)
# Out:
# Metallic       9794
# NaN            5772
# Uni/basic       347
# Perl effect       6
# Name: Paint_Type, dtype: int64

# %%
df.drop("Paint Type", axis=1, inplace=True)

# %% [markdown]
# ## Upholstery

# %%
df['Upholstery'].astype('str').value_counts(dropna=False)
# Out:
# ['\nCloth, Black\n']           5821
# nan                            3720
# ['\nPart leather, Black\n']    1121
# ['\nCloth\n']                  1005
# ['\nCloth, Grey\n']             891
# ['\nCloth, Other\n']            639
# ['\nFull leather, Black\n']     575
# ['\nBlack\n']                   491
# ['\nGrey\n']                    273
# ['\nOther, Other\n']            182
# ['\nPart leather\n']            140
# ['\nFull leather\n']            139
# ['\nPart leather, Grey\n']      116
# ['\nFull leather, Brown\n']     116
# ['\nOther, Black\n']            110
# ['\nFull leather, Other\n']      72
# ['\nFull leather, Grey\n']       67
# ['\nPart leather, Other\n']      65
# ['\nOther\n']                    56
# ['\nPart leather, Brown\n']      50
# ['\nalcantara, Black\n']         47
# ['\nFull leather, Beige\n']      36
# ['\nVelour, Black\n']            36
# ['\nCloth, Brown\n']             28
# ['\nVelour\n']                   16
# ['\nOther, Grey\n']              15
# ['\nCloth, Beige\n']             13
# ['\nBrown\n']                    12
# ['\nCloth, Blue\n']              12
# ['\nCloth, White\n']              8
# ['\nVelour, Grey\n']              8
# ['\nalcantara, Grey\n']           6
# ['\nCloth, Red\n']                5
# ['\nOther, Yellow\n']             4
# ['\nPart leather, Red\n']         3
# ['\nBeige\n']                     3
# ['\nPart leather, Beige\n']       2
# ['\nalcantara, Other\n']          2
# ['\nBlue\n']                      2
# ['\nFull leather, Blue\n']        2
# ['\nPart leather, White\n']       2
# ['\nalcantara\n']                 2
# ['\nWhite\n']                     2
# ['\nOther, Brown\n']              1
# ['\nCloth, Orange\n']             1
# ['\nFull leather, White\n']       1
# ['\nFull leather, Red\n']         1
# Name: Upholstery, dtype: int64

# %%
df["Upholstery"] = [item[0] if type(item) == list else item for item in df.Upholstery]

# %%
df["Upholstery"].value_counts(dropna=False)
# Out:
# \nCloth, Black\n           5821
# NaN                        3720
# \nPart leather, Black\n    1121
# \nCloth\n                  1005
# \nCloth, Grey\n             891
# \nCloth, Other\n            639
# \nFull leather, Black\n     575
# \nBlack\n                   491
# \nGrey\n                    273
# \nOther, Other\n            182
# \nPart leather\n            140
# \nFull leather\n            139
# \nPart leather, Grey\n      116
# \nFull leather, Brown\n     116
# \nOther, Black\n            110
# \nFull leather, Other\n      72
# \nFull leather, Grey\n       67
# \nPart leather, Other\n      65
# \nOther\n                    56
# \nPart leather, Brown\n      50
# \nalcantara, Black\n         47
# \nVelour, Black\n            36
# \nFull leather, Beige\n      36
# \nCloth, Brown\n             28
# \nVelour\n                   16
# \nOther, Grey\n              15
# \nCloth, Beige\n             13
# \nBrown\n                    12
# \nCloth, Blue\n              12
# \nCloth, White\n              8
# \nVelour, Grey\n              8
# \nalcantara, Grey\n           6
# \nCloth, Red\n                5
# \nOther, Yellow\n             4
# \nPart leather, Red\n         3
# \nBeige\n                     3
# \nFull leather, Blue\n        2
# \nalcantara, Other\n          2
# \nPart leather, Beige\n       2
# \nPart leather, White\n       2
# \nBlue\n                      2
# \nalcantara\n                 2
# \nWhite\n                     2
# \nFull leather, White\n       1
# \nOther, Brown\n              1
# \nFull leather, Red\n         1
# \nCloth, Orange\n             1
# Name: Upholstery, dtype: int64

# %%
df["Upholstery"] = df.Upholstery.str.strip("\n").str.split(", ")

# %%
df["Upholstery"].astype('str').value_counts(dropna=False)
# Out:
# ['Cloth', 'Black']           5821
# nan                          3720
# ['Part leather', 'Black']    1121
# ['Cloth']                    1005
# ['Cloth', 'Grey']             891
# ['Cloth', 'Other']            639
# ['Full leather', 'Black']     575
# ['Black']                     491
# ['Grey']                      273
# ['Other', 'Other']            182
# ['Part leather']              140
# ['Full leather']              139
# ['Full leather', 'Brown']     116
# ['Part leather', 'Grey']      116
# ['Other', 'Black']            110
# ['Full leather', 'Other']      72
# ['Full leather', 'Grey']       67
# ['Part leather', 'Other']      65
# ['Other']                      56
# ['Part leather', 'Brown']      50
# ['alcantara', 'Black']         47
# ['Full leather', 'Beige']      36
# ['Velour', 'Black']            36
# ['Cloth', 'Brown']             28
# ['Velour']                     16
# ['Other', 'Grey']              15
# ['Cloth', 'Beige']             13
# ['Brown']                      12
# ['Cloth', 'Blue']              12
# ['Cloth', 'White']              8
# ['Velour', 'Grey']              8
# ['alcantara', 'Grey']           6
# ['Cloth', 'Red']                5
# ['Other', 'Yellow']             4
# ['Part leather', 'Red']         3
# ['Beige']                       3
# ['alcantara']                   2
# ['Blue']                        2
# ['Part leather', 'White']       2
# ['alcantara', 'Other']          2
# ['Full leather', 'Blue']        2
# ['White']                       2
# ['Part leather', 'Beige']       2
# ['Other', 'Brown']              1
# ['Cloth', 'Orange']             1
# ['Full leather', 'Red']         1
# ['Full leather', 'White']       1
# Name: Upholstery, dtype: int64

# %%
u_type = ["Cloth", 'Part leather', 'Full leather', 'Velour', 'alcantara']

df["Upholstery_type"] = df["Upholstery"].apply(lambda x : x[0] if type(x) == list and x[0] in u_type else np.nan)

# %%
df["Upholstery_type"].value_counts(dropna=False)
# Out:
# Cloth           8423
# NaN             4871
# Part leather    1499
# Full leather    1009
# Velour            60
# alcantara         57
# Name: Upholstery_type, dtype: int64

# %%
color = ['Black', 'Grey', 'Brown', 'Beige', 'White', 'Blue', 'Red', 'Yellow', 'Orange']

def color_finder(x):
    if type(x) == list and len(x) == 2:
        return x[1]
    elif type(x) == list and x[0] in color:
        return x[0]
    else:
        return np.nan
    
df['Upholstery_color'] = df.Upholstery.apply(color_finder)

# %%
df["Upholstery_color"].value_counts(dropna=False)
# Out:
# Black     8201
# NaN       5078
# Grey      1376
# Other      960
# Brown      207
# Beige       54
# Blue        16
# White       13
# Red          9
# Yellow       4
# Orange       1
# Name: Upholstery_color, dtype: int64

# %%
df.drop("Upholstery", axis=1, inplace=True)

# %% [markdown]
# ## Nr. of Doors

# %%
df["Nr. of Doors"].astype('str').value_counts(dropna=False)
# Out:
# ['\n5\n']    11575
# ['\n4\n']     3079
# ['\n3\n']      832
# ['\n2\n']      219
# nan            212
# ['\n1\n']        1
# ['\n7\n']        1
# Name: Nr. of Doors, dtype: int64

# %%
df['Nr_of_Doors'] = df['Nr. of Doors'].str[0].str.strip('\n').astype('float')

# %%
df["Nr_of_Doors"].value_counts(dropna=False)
# Out:
# 5.00    11575
# 4.00     3079
# 3.00      832
# 2.00      219
# nan       212
# 7.00        1
# 1.00        1
# Name: Nr_of_Doors, dtype: int64

# %%
df.drop("Nr. of Doors", axis=1, inplace=True)

# %% [markdown]
# ## Nr. of Seats

# %%
df["Nr. of Seats"].astype('str').value_counts(dropna=False)
# Out:
# ['\n5\n']    13336
# ['\n4\n']     1125
# nan            977
# ['\n7\n']      362
# ['\n2\n']      116
# ['\n6\n']        2
# ['\n3\n']        1
# Name: Nr. of Seats, dtype: int64

# %%
df['Nr_of_Seats'] = df['Nr. of Seats'].str[0].str.strip('\n').astype('float')

# %%
df["Nr_of_Seats"].value_counts(dropna=False)
# Out:
# 5.00    13336
# 4.00     1125
# nan       977
# 7.00      362
# 2.00      116
# 6.00        2
# 3.00        1
# Name: Nr_of_Seats, dtype: int64

# %%
df.drop("Nr. of Seats", axis=1, inplace=True)

# %% [markdown]
# ## Model Code

# %%
df["Model Code"].astype('str').value_counts(dropna=False)
# Out:
# nan                 10941
# ['\n0035/BCB\n']      268
# ['\n0588/BNO\n']      245
# ['\n0588/BDB\n']      206
# ['\n0588/BHX\n']      188
#                     ...
# ['\n0035/BEM\n']        1
# ['\n0035/bgp\n']        1
# ['\n0035/ASN\n']        1
# ['\n0035/BAA\n']        1
# ['\n0588/AZY\n']        1
# Name: Model Code, Length: 233, dtype: int64

# %%
df.drop("Model Code", axis=1, inplace=True)

# %% [markdown]
# ## Gearing Type

# %%
df["Gearing Type"].astype('str').value_counts(dropna=False)
# Out:
# ['\n', 'Manual', '\n']            8153
# ['\n', 'Automatic', '\n']         7297
# ['\n', 'Semi-automatic', '\n']     469
# Name: Gearing Type, dtype: int64

# %%
df['Gearing_Type'] = df['Gearing Type'].str[1]

# %%
df["Gearing_Type"].value_counts(dropna=False)
# Out:
# Manual            8153
# Automatic         7297
# Semi-automatic     469
# Name: Gearing_Type, dtype: int64

# %%
df.drop("Gearing Type", axis=1, inplace=True)

# %% [markdown]
# ## Displacement

# %%
df["Displacement"].astype('str').value_counts(dropna=False)
# Out:
# ['\n1,598 cc\n']     4761
# ['\n999 cc\n']       2438
# ['\n1,398 cc\n']     1314
# ['\n1,399 cc\n']      749
# ['\n1,229 cc\n']      677
# ['\n1,956 cc\n']      670
# ['\n1,461 cc\n']      595
# ['\n1,490 cc\n']      559
# nan                   496
# ['\n1,422 cc\n']      467
# ['\n1,197 cc\n']      353
# ['\n898 cc\n']        351
# ['\n1,395 cc\n']      320
# ['\n1,968 cc\n']      301
# ['\n1,149 cc\n']      288
# ['\n1,618 cc\n']      212
# ['\n1,798 cc\n']      210
# ['\n1,498 cc\n']      196
# ['\n1,600 cc\n']      130
# ['\n1,248 cc\n']      110
# ['\n1,997 cc\n']      103
# ['\n1,364 cc\n']      102
# ['\n1,400 cc\n']       90
# ['\n998 cc\n']         72
# ['\n1,500 cc\n']       50
# ['\n2,000 cc\n']       46
# ['\n1,000 cc\n']       40
# ['\n1 cc\n']           36
# ['\n1,998 cc\n']       25
# ['\n2,480 cc\n']       20
# ['\n1,984 cc\n']       18
# ['\n1,200 cc\n']       18
# ['\n899 cc\n']         11
# ['\n1,397 cc\n']       11
# ['\n160 cc\n']          6
# ['\n929 cc\n']          5
# ['\n1,499 cc\n']        5
# ['\n997 cc\n']          4
# ['\n1,596 cc\n']        4
# ['\n900 cc\n']          4
# ['\n139 cc\n']          4
# ['\n1,199 cc\n']        3
# ['\n1,396 cc\n']        3
# ['\n1,599 cc\n']        3
# ['\n1,495 cc\n']        2
# ['\n995 cc\n']          2
# ['\n2 cc\n']            2
# ['\n1,589 cc\n']        2
# ['\n1,300 cc\n']        2
# ['\n1,800 cc\n']        1
# ['\n1,584 cc\n']        1
# ['\n1,496 cc\n']        1
# ['\n140 cc\n']          1
# ['\n1,368 cc\n']        1
# ['\n1,533 cc\n']        1
# ['\n1,100 cc\n']        1
# ['\n1,995 cc\n']        1
# ['\n1,195 cc\n']        1
# ['\n973 cc\n']          1
# ['\n1,239 cc\n']        1
# ['\n1,686 cc\n']        1
# ['\n1,333 cc\n']        1
# ['\n1,198 cc\n']        1
# ['\n16,000 cc\n']       1
# ['\n1,856 cc\n']        1
# ['\n1,369 cc\n']        1
# ['\n996 cc\n']          1
# ['\n890 cc\n']          1
# ['\n2,967 cc\n']        1
# ['\n15,898 cc\n']       1
# ['\n1,350 cc\n']        1
# ['\n122 cc\n']          1
# ['\n54 cc\n']           1
# ['\n1,696 cc\n']        1
# ['\n1,896 cc\n']        1
# ['\n1,390 cc\n']        1
# ['\n1,568 cc\n']        1
# ['\n1,580 cc\n']        1
# Name: Displacement, dtype: int64

# %%
df["Displacement_cc"] = df.Displacement.str[0].str.strip('\n').str.replace(',', '').str.extract('(\d{1,5})').astype("float") # str.extract('(\d+)')

# %%
df["Displacement_cc"].value_counts(dropna=False)
# Out:
# 1598.00     4761
# 999.00      2438
# 1398.00     1314
# 1399.00      749
# 1229.00      677
# 1956.00      670
# 1461.00      595
# 1490.00      559
# nan          496
# 1422.00      467
# 1197.00      353
# 898.00       351
# 1395.00      320
# 1968.00      301
# 1149.00      288
# 1618.00      212
# 1798.00      210
# 1498.00      196
# 1600.00      130
# 1248.00      110
# 1997.00      103
# 1364.00      102
# 1400.00       90
# 998.00        72
# 1500.00       50
# 2000.00       46
# 1000.00       40
# 1.00          36
# 1998.00       25
# 2480.00       20
# 1984.00       18
# 1200.00       18
# 899.00        11
# 1397.00       11
# 160.00         6
# 1499.00        5
# 929.00         5
# 900.00         4
# 997.00         4
# 1596.00        4
# 139.00         4
# 1396.00        3
# 1599.00        3
# 1199.00        3
# 995.00         2
# 1495.00        2
# 2.00           2
# 1300.00        2
# 1589.00        2
# 16000.00       1
# 1568.00        1
# 1333.00        1
# 15898.00       1
# 1686.00        1
# 1100.00        1
# 1369.00        1
# 1239.00        1
# 996.00         1
# 1533.00        1
# 973.00         1
# 1584.00        1
# 1368.00        1
# 1696.00        1
# 1995.00        1
# 1896.00        1
# 890.00         1
# 122.00         1
# 54.00          1
# 1496.00        1
# 1580.00        1
# 1856.00        1
# 1800.00        1
# 1195.00        1
# 2967.00        1
# 1390.00        1
# 140.00         1
# 1350.00        1
# 1198.00        1
# Name: Displacement_cc, dtype: int64

# %%
df.drop("Displacement", axis=1, inplace=True)

# %% [markdown]
# ## Cylinders

# %%
df["Cylinders"].astype('str').value_counts(dropna=False)
# Out:
# ['\n4\n']    8105
# nan          5680
# ['\n3\n']    2104
# ['\n5\n']      22
# ['\n6\n']       3
# ['\n2\n']       2
# ['\n8\n']       2
# ['\n1\n']       1
# Name: Cylinders, dtype: int64

# %%
df["Cylinders"] = df.Cylinders.str[0].str.strip('\n').astype("float")

# %%
df["Cylinders"].value_counts(dropna=False)
# Out:
# 4.00    8105
# nan     5680
# 3.00    2104
# 5.00      22
# 6.00       3
# 2.00       2
# 8.00       2
# 1.00       1
# Name: Cylinders, dtype: int64

# %% [markdown]
# ## Weight

# %%
df["Weight"].astype('str').value_counts(dropna=False)
# Out:
# nan                 6974
# ['\n1,163 kg\n']     574
# ['\n1,360 kg\n']     356
# ['\n1,165 kg\n']     301
# ['\n1,335 kg\n']     242
#                     ...
# ['\n900 kg\n']         1
# ['\n1,591 kg\n']       1
# ['\n1,294 kg\n']       1
# ['\n1,797 kg\n']       1
# ['\n1,761 kg\n']       1
# Name: Weight, Length: 435, dtype: int64

# %%
df["Weight_kg"] = df.Weight.str[0].str.strip('\n').str.replace(',', '').str.extract('(\d{1,6})').astype('float') # str.extract('(\d+)')

# %%
df["Weight_kg"].value_counts(dropna=False)
# Out:
# nan        6974
# 1163.00     574
# 1360.00     356
# 1165.00     301
# 1335.00     242
#            ...
# 900.00        1
# 1650.00       1
# 1428.00       1
# 2355.00       1
# 1523.00       1
# Name: Weight_kg, Length: 435, dtype: int64

# %%
df.drop("Weight", axis=1, inplace=True)

# %% [markdown]
# ## Drive chain

# %%
df["Drive chain"].astype('str').value_counts(dropna=False)
# Out:
# ['\nfront\n']    8886
# nan              6858
# ['\n4WD\n']       171
# ['\nrear\n']        4
# Name: Drive chain, dtype: int64

# %%
df['Drive_chain'] = df['Drive chain'].str[0].str.strip('\n')

# %%
df["Drive_chain"].value_counts(dropna=False)
# Out:
# front    8886
# NaN      6858
# 4WD       171
# rear        4
# Name: Drive_chain, dtype: int64

# %%
df.drop("Drive chain", axis=1, inplace=True)

# %% [markdown]
# ## Fuel

# %%
df["Fuel"].astype('str').value_counts(dropna=False)
# Out:
# ['\n', 'Diesel (Particulate Filter)', '\n']                                                                                                       4315
# ['\n', 'Super 95', '\n']                                                                                                                          3338
# ['\n', 'Gasoline', '\n']                                                                                                                          3175
# ['\n', 'Diesel', '\n']                                                                                                                            2984
# ['\n', 'Super 95 / Regular/Benzine 91', '\n']                                                                                                      424
# ['\n', 'Regular/Benzine 91', '\n']                                                                                                                 354
# ['\n', 'Super E10 95', '\n']                                                                                                                       331
# ['\n', 'Super 95 (Particulate Filter)', '\n']                                                                                                      268
# ['\n', 'Super 95 / Super E10 95', '\n']                                                                                                            131
# ['\n', 'Regular/Benzine 91 (Particulate Filter)', '\n']                                                                                            100
# ['\n', 'Super 95 / Super Plus 98', '\n']                                                                                                            85
# ['\n', 'Gasoline (Particulate Filter)', '\n']                                                                                                       77
# ['\n', 'Super 95 / Super Plus 98 / Super E10 95 / Super Plus E10 98', '\n']                                                                         40
# ['\n', 'Super E10 95 / Super 95', '\n']                                                                                                             38
# ['\n', 'CNG', '\n']                                                                                                                                 33
# ['\n', 'Super 95 / Super E10 95 (Particulate Filter)', '\n']                                                                                        25
# ['\n', 'Super E10 95 / Super 95 / Super Plus 98 / Super Plus E10 98', '\n']                                                                         19
# ['\n', 'LPG', '\n']                                                                                                                                 16
# ['\n', 'Super 95 / Super Plus 98 (Particulate Filter)', '\n']                                                                                       14
# ['\n', 'Regular/Benzine 91 / Super 95 / Super Plus 98 / Regular/Benzine E10 91 / Super E10 95 / Super Plus E10 98', '\n']                           13
# ['\n', 'Regular/Benzine E10 91', '\n']                                                                                                              11
# ['\n', 'Liquid petroleum gas (LPG)', '\n']                                                                                                          10
# ['\n', 'Super 95 / Super Plus 98 / Super E10 95', '\n']                                                                                              8
# ['\n', 'Regular/Benzine 91 / Regular/Benzine E10 91', '\n']                                                                                          7
# ['\n', 'Super E10 95 (Particulate Filter)', '\n']                                                                                                    7
# ['\n', 'Super Plus 98', '\n']                                                                                                                        7
# ['\n', 'Super 95 / Regular/Benzine 91 / Super Plus 98 / Regular/Benzine E10 91 / Super E10 95 / Super Plus E10 98', '\n']                            7
# ['\n', 'Super 95 / Super Plus 98 / Super Plus E10 98 / Super E10 95', '\n']                                                                          5
# ['\n', 'Others', '\n']                                                                                                                               5
# ['\n', 'Super 95 / Super E10 95 / Super Plus E10 98 / Super Plus 98', '\n']                                                                          4
# ['\n', 'Electric/Gasoline', '\n']                                                                                                                    4
# ['\n', 'Super E10 95 / Super Plus E10 98', '\n']                                                                                                     4
# ['\n', 'Regular/Benzine 91 / Super 95 / Super Plus 98 / Regular/Benzine E10 91 / Super Plus E10 98 / Super E10 95', '\n']                            4
# ['\n', 'Super 95 / Super Plus 98 / Super E10 95 / Super Plus E10 98 (Particulate Filter)', '\n']                                                     4
# ['\n', 'Super E10 95 / Super 95 / Super Plus 98 / Super Plus E10 98 (Particulate Filter)', '\n']                                                     3
# ['\n', 'Super E10 95 / Super 95 / Super Plus 98', '\n']                                                                                              3
# ['\n', 'CNG (Particulate Filter)', '\n']                                                                                                             3
# ['\n', 'Regular/Benzine 91 / Super 95 / Super Plus 98 / Super Plus E10 98 / Super E10 95 / Regular/Benzine E10 91', '\n']                            2
# ['\n', 'Super 95 / Regular/Benzine 91 / Super Plus 98', '\n']                                                                                        2
# ['\n', 'Super E10 95 / Regular/Benzine 91', '\n']                                                                                                    2
# ['\n', 'Super Plus 98 / Super 95 / Super Plus E10 98', '\n']                                                                                         1
# ['\n', 'Regular/Benzine 91 / Super 95', '\n']                                                                                                        1
# ['\n', 'Super Plus 98 / Super E10 95', '\n']                                                                                                         1
# ['\n', 'Regular/Benzine 91 / Super 95 / Super E10 95', '\n']                                                                                         1
# ['\n', 'Regular/Benzine E10 91 / Super E10 95 / Super Plus E10 98 / Super Plus 98 / Super 95 / Regular/Benzine 91', '\n']                            1
# ['\n', 'Super 95 / Super Plus 98 / Regular/Benzine E10 91 / Super Plus E10 98 / Super E10 95 / Regular/Benzine 91', '\n']                            1
# ['\n', 'Domestic gas H', '\n']                                                                                                                       1
# ['\n', 'Super 95 / Regular/Benzine 91 / Super E10 95 / Super Plus 98 / Super Plus E10 98 / Regular/Benzine E10 91', '\n']                            1
# ['\n', 'Super Plus E10 98 / Super 95 / Super Plus 98 / Super E10 95', '\n']                                                                          1
# ['\n', 'Super Plus 98 / Super 95 / Super E10 95', '\n']                                                                                              1
# ['\n', 'Super 95 / Super E10 95 / Super Plus 98', '\n']                                                                                              1
# ['\n', 'Super 95 / Regular/Benzine 91 / Super Plus 98 / Regular/Benzine E10 91 / Super Plus E10 98 / Super E10 95', '\n']                            1
# ['\n', 'Electric', '\n']                                                                                                                             1
# ['\n', 'Super 95 / Super E10 95 / Super Plus E10 98', '\n']                                                                                          1
# ['\n', 'Super 95 / Regular/Benzine E10 91', '\n']                                                                                                    1
# ['\n', 'Regular/Benzine 91 / Super 95 / Super Plus 98 / Super Plus E10 98 / Super E10 95 / Regular/Benzine E10 91 (Particulate Filter)', '\n']       1
# ['\n', 'Regular/Benzine 91 / Super 95 / Super E10 95 / Super Plus E10 98 / Super Plus 98 / Regular/Benzine E10 91', '\n']                            1
# ['\n', 'Super 95 / Regular/Benzine 91 (Particulate Filter)', '\n']                                                                                   1
# ['\n', 'Regular/Benzine 91 / Super 95 / Super Plus E10 98 / Super E10 95 / Regular/Benzine E10 91 / Super Plus 98', '\n']                            1
# ['\n', 'Super 95 / Super E10 95 / Regular/Benzine 91', '\n']                                                                                         1
# ['\n', 'Super E10 95 / Regular/Benzine 91 / Super 95 / Super Plus 98 / Regular/Benzine E10 91 / Super Plus E10 98', '\n']                            1
# ['\n', 'Regular/Benzine 91 / Super Plus 98 / Regular/Benzine E10 91 / Super 95 / Super E10 95 / Super Plus E10 98', '\n']                            1
# ['\n', 'Regular/Benzine E10 91 / Regular/Benzine 91 / Super 95 / Super Plus 98 / Super E10 95 / Super Plus E10 98', '\n']                            1
# ['\n', 'Super 95 / Regular/Benzine E10 91 / Super E10 95', '\n']                                                                                     1
# ['\n', 'Biogas', '\n']                                                                                                                               1
# ['\n', 'Super 95 / Biodiesel', '\n']                                                                                                                 1
# ['\n', 'Super 95 / Super Plus 98 / Super Plus E10 98', '\n']                                                                                         1
# ['\n', 'Super Plus 98 / Regular/Benzine 91', '\n']                                                                                                   1
# ['\n', 'Super 95 / Regular/Benzine 91 / Super E10 95 / Super Plus E10 98 / Super Plus 98', '\n']                                                     1
# ['\n', 'Super Plus E10 98', '\n']                                                                                                                    1
# ['\n', 'Super 95 / Regular/Benzine 91 / Super E10 95 / Super Plus E10 98 / Super Plus 98 / Regular/Benzine E10 91', '\n']                            1
# ['\n', 'Regular/Benzine 91 / Super 95 / Regular/Benzine E10 91 / Super E10 95 / Super Plus 98 / Super Plus E10 98', '\n']                            1
# ['\n', 'Regular/Benzine 91 / Super 95 / Super Plus 98', '\n']                                                                                        1
# ['\n', 'Others (Particulate Filter)', '\n']                                                                                                          1
# ['\n', 'Super E10 95 / Regular/Benzine 91 / Regular/Benzine E10 91 / Super 95', '\n']                                                                1
# ['\n', 'Regular/Benzine 91 / Super 95 / Super E10 95 / Regular/Benzine E10 91', '\n']                                                                1
# ['\n', 'Regular/Benzine 91 / Super 95 / Regular/Benzine E10 91', '\n']                                                                               1
# Name: Fuel, dtype: int64

# %%
df["Fuel"] = df.Fuel.str[1].str.split("/").str[0].str.strip()

# %%
df["Fuel"].value_counts(dropna=False)
# Out:
# Diesel (Particulate Filter)          4315
# Super 95                             4100
# Gasoline                             3175
# Diesel                               2984
# Regular                               503
# Super E10 95                          402
# Super 95 (Particulate Filter)         268
# Gasoline (Particulate Filter)          77
# CNG                                    33
# LPG                                    16
# Super Plus 98                          11
# Liquid petroleum gas (LPG)             10
# Super E10 95 (Particulate Filter)       7
# Electric                                5
# Others                                  5
# CNG (Particulate Filter)                3
# Super Plus E10 98                       2
# Others (Particulate Filter)             1
# Domestic gas H                          1
# Biogas                                  1
# Name: Fuel, dtype: int64

# %%
df["Fuel"] = df.Fuel.str.split("(").str[0].str.strip()

# %%
df["Fuel"].value_counts(dropna=False)
# Out:
# Diesel                  7299
# Super 95                4368
# Gasoline                3252
# Regular                  503
# Super E10 95             409
# CNG                       36
# LPG                       16
# Super Plus 98             11
# Liquid petroleum gas      10
# Others                     6
# Electric                   5
# Super Plus E10 98          2
# Biogas                     1
# Domestic gas H             1
# Name: Fuel, dtype: int64

# %%
benzine = ["Gasoline", "Super 95", "Regular", "Super E10 95", "Super Plus 98", "Super Plus E10 98", "Others"]
lpg = ["LPG", "Liquid petroleum gas", "CNG", "Biogas", "Domestic gas H"]

def fueltype(x):
    if x in benzine:
        return "Benzine"
    elif x in lpg:
        return "LPG/CNG"
    else:
        return x

df["Fuel"] = df.Fuel.apply(fueltype)

# %%
df.Fuel.value_counts(dropna=False)
# Out:
# Benzine     8551
# Diesel      7299
# LPG/CNG       64
# Electric       5
# Name: Fuel, dtype: int64

# %%
df[df.Fuel == "Electric"][["make_model", "body_type", "CO2 Emission", "Gears", "hp_kW", "Consumption", "price"]]
# Out:
#          make_model body_type              CO2 Emission    Gears  hp_kW  \
# 3356        Audi A3   Compact                       NaN  [\n6\n] 150.00
# 3612        Audi A3    Sedans  [\n36 g CO2/km (comb)\n]  [\n6\n] 110.00
# 3615        Audi A3    Sedans  [\n36 g CO2/km (comb)\n]  [\n6\n] 110.00
# 3617        Audi A3    Sedans  [\n36 g CO2/km (comb)\n]  [\n6\n] 110.00
# 13397  Renault Clio    Sedans              [[], [], []]      NaN    nan
#
#                                  Consumption  price
# 3356                                     NaN  24950
# 3612   [\n, 1.6 l/100 km (comb), \n, \n, \n]  38450
# 3615   [\n, 1.6 l/100 km (comb), \n, \n, \n]  35899
# 3617   [\n, 1.6 l/100 km (comb), \n, \n, \n]  38000
# 13397                                    NaN   8490

# %%
#alternative method

#df["fuel_new"] = df.Fuel.str[1]
#diesel_bool = df["fuel_new"].str.contains("diesel", case = False, regex = True)
#lpg_bool = df["fuel_new"].str.contains("lpg|cng|bio|domestic|electric", case=False, regex=True)
#df.loc[diesel_bool, "fuel_new"] = "Diesel"
#df.loc[lpg_bool, "fuel_new"] = "LPG/CNG"
#benz = list(df.fuel_new.loc[lambda x : x != "Diesel"][lambda x : x != "LPG/CNG"].index)
#df.fuel_new.iloc[benz] = "Benzine"

# %% [markdown]
# ## Consumption

# %%
df["Consumption"].astype('str').value_counts(dropna=False)
# Out:
# nan                                                                                1906
# [['3.9 l/100 km (comb)'], ['4.1 l/100 km (city)'], ['3.7 l/100 km (country)']]      304
# [['4.2 l/100 km (comb)'], ['5 l/100 km (city)'], ['3.7 l/100 km (country)']]        276
# [['5.4 l/100 km (comb)'], ['6.8 l/100 km (city)'], ['4.5 l/100 km (country)']]      257
# [['3.8 l/100 km (comb)'], ['4.3 l/100 km (city)'], ['3.5 l/100 km (country)']]      253
#                                                                                    ...
# [['5.6 l/100 km (comb)'], ['7.6 l/100 km (city)'], ['4.5 l/100 km (country)']]        1
# [['6.7 l/100 km (comb)'], ['8.3 l/100 km (city)'], ['5.7 l/100 km (country)']]        1
# [['5.3 l/100 km (comb)'], ['6 l/100 km (city)'], ['5 l/100 km (country)']]            1
# [['7.4 l/100 km (comb)'], ['10.4 l/100 km (city)'], ['6.4 l/100 km (country)']]       1
# [['3.7 l/100 km (comb)'], ['4.5 l/100 km (city)'], ['3.3 l/100 km (country)']]        1
# Name: Consumption, Length: 882, dtype: int64

# %%
def cons_comb(x):
    
    if type(x)==list and len(x)==3:
        if x[0] != []: return x[0][0]
        else: return None
        
    if type(x)==list and len(x)==5:
        return x[1]
    
    if type(x)==list and len(x)==7:
        return x[1]
    
    else:
        return None

# %%
def cons_city(x):
    
    if type(x)==list and len(x)==3:
        if x[1] != []: return x[1][0]
        else: return None
        
    if type(x)==list and len(x)==5:
        return None
    
    if type(x)==list and len(x)==7:
        return x[3]
    
    else:
        return None

# %%
def cons_country(x):
    
    if type(x)==list and len(x)==3:
        if x[2] != []: return x[2][0]
        else: return None
        
    if type(x)==list and len(x)==5:
        return None
    
    if type(x)==list and len(x)==7:
        return x[5]
    
    else:
        return None

# %%
df['cons_comb'] = df.Consumption.apply(cons_comb).str.extract('(\d{1,2}.\d|\d{1,3})').astype("float") # str.extract('(\S+)')
df['cons_city'] = df.Consumption.apply(cons_city).str.extract('(\d{1,2}.\d|\d{1,3})').astype("float")
df['cons_country'] = df.Consumption.apply(cons_country).str.extract('(\d{1,2}.\d|\d{1,3})').astype("float")

# %%
df["cons_comb"].value_counts(dropna=False).head()
# Out:
# nan     2033
# 5.40     770
# 3.90     733
# 4.00     713
# 5.10     657
# Name: cons_comb, dtype: int64

# %%
df["cons_city"].value_counts(dropna=False).head()
# Out:
# nan     2436
# 5.00     669
# 5.80     633
# 4.50     580
# 4.30     533
# Name: cons_city, dtype: int64

# %%
df["cons_country"].value_counts(dropna=False).head()
# Out:
# nan     2376
# 4.20    1178
# 3.70    1089
# 4.40     898
# 4.50     848
# Name: cons_country, dtype: int64

# %%
df.drop('Consumption', axis=1,inplace=True)

# %% [markdown]
# ## CO2 Emission

# %%
df["CO2 Emission"].astype('str').value_counts(dropna=False)
# Out:
# nan                            1808
# ['\n120 g CO2/km (comb)\n']     740
# [[], [], []]                    628
# ['\n99 g CO2/km (comb)\n']      545
# ['\n97 g CO2/km (comb)\n']      537
#                                ...
# ['\n331 g CO2/km (comb)\n']       1
# ['\n190 g CO2/km (comb)\n']       1
# ['\n14 g CO2/km (comb)\n']        1
# ['\n181 g CO2/km (comb)\n']       1
# ['\n253 g CO2/km (comb)\n']       1
# Name: CO2 Emission, Length: 124, dtype: int64

# %%
df["CO2_Emission"] = df['CO2 Emission'].str[0].str.strip().str.replace(',', '').str.extract('(\d+)').astype('float')

#df["CO2_Emission"] = [item[0] if type(item) == list else item for item in df["CO2 Emission"]]
#df["CO2_Emission"] = df["CO2_Emission"].str.strip("\n").str.rstrip(" g CO2/km (comb)").str.replace(",", "").astype("float")

# %%
df["CO2_Emission"].value_counts(dropna=False)
# Out:
# nan         2436
# 120.00       740
# 99.00        545
# 97.00        537
# 104.00       501
#             ...
# 184.00         1
# 181.00         1
# 171.00         1
# 12324.00       1
# 253.00         1
# Name: CO2_Emission, Length: 123, dtype: int64

# %%
df.drop("CO2 Emission", axis=1, inplace=True)

# %% [markdown]
# ## Emission Class

# %%
df["Emission Class"].astype('str').value_counts(dropna=False)
# Out:
# ['\nEuro 6\n']          10139
# nan                      3021
# ['\nEuro 6d-TEMP\n']     1845
# [[], [], []]              607
# ['\nEuro 6c\n']           127
# ['\nEuro 5\n']             78
# ['\nEuro 6d\n']            62
# ['\nEuro 4\n']             40
# Name: Emission Class, dtype: int64

# %%
df["Emission_Class"] = [item[0] if type(item) == list else item for item in df["Emission Class"]]
df["Emission_Class"] = df["Emission_Class"].str.strip("\n")

# %%
df["Emission_Class"].value_counts(dropna=False)
# Out:
# Euro 6          10139
# NaN              3628
# Euro 6d-TEMP     1845
# Euro 6c           127
# Euro 5             78
# Euro 6d            62
# Euro 4             40
# Name: Emission_Class, dtype: int64

# %%
df.replace({"Emission_Class" : {"Euro 6d-TEMP": "Euro 6", "Euro 6c": "Euro 6", "Euro 6d": "Euro 6"}}, regex=True, inplace=True)

# %%
df["Emission_Class"].value_counts(dropna=False)
# Out:
# Euro 6    12173
# NaN        3628
# Euro 5       78
# Euro 4       40
# Name: Emission_Class, dtype: int64

# %%
df.drop("Emission Class", axis=1, inplace=True)

# %% [markdown]
# ## Emission Label

# %%
df["Emission Label"].astype('str').value_counts(dropna=False)
# Out:
# nan                       11934
# ['\n4 (Green)\n']          3553
# ['\n1 (No sticker)\n']      381
# [[], [], []]                 40
# ['\n5 (Blue)\n']              8
# ['\n3 (Yellow)\n']            2
# ['\n2 (Red)\n']               1
# Name: Emission Label, dtype: int64

# %%
df.drop("Emission Label", axis=1, inplace=True)

# %% [markdown]
# ## Gears

# %%
df["Gears"].astype('str').value_counts(dropna=False)
# Out:
# ['\n6\n']     5822
# nan           4712
# ['\n5\n']     3239
# ['\n7\n']     1908
# ['\n8\n']      224
# ['\n9\n']        6
# ['\n1\n']        2
# ['\n4\n']        2
# ['\n3\n']        2
# ['\n2\n']        1
# ['\n50\n']       1
# Name: Gears, dtype: int64

# %%
df["Gears"] = df.Gears.str[0].str.strip('\n')

# %%
df["Gears"].value_counts(dropna=False)
# Out:
# 6      5822
# NaN    4712
# 5      3239
# 7      1908
# 8       224
# 9         6
# 4         2
# 3         2
# 1         2
# 2         1
# 50        1
# Name: Gears, dtype: int64

# %% [markdown]
# ## Country version

# %%
df["Country version"].astype('str').value_counts(dropna=False)
# Out:
# nan                       8333
# ['\nGermany\n']           4502
# ['\nItaly\n']             1038
# ['\nEuropean Union\n']     507
# ['\nNetherlands\n']        464
# ['\nSpain\n']              325
# ['\nBelgium\n']            314
# ['\nAustria\n']            208
# ['\nCzech Republic\n']      52
# ['\nPoland\n']              49
# ['\nFrance\n']              38
# ['\nDenmark\n']             33
# ['\nHungary\n']             28
# ['\nJapan\n']                8
# ['\nCroatia\n']              4
# ['\nSlovakia\n']             4
# ['\nSweden\n']               3
# ['\nBulgaria\n']             2
# ['\nRomania\n']              2
# ['\nSerbia\n']               1
# ['\nSwitzerland\n']          1
# ['\nEgypt\n']                1
# ['\nLuxembourg\n']           1
# ['\nSlovenia\n']             1
# Name: Country version, dtype: int64

# %%
df.drop("Country version", axis=1, inplace=True)

# %% [markdown]
# ## Comfort_Convenience

# %%
df["Comfort_Convenience"].astype('str').value_counts(dropna=False).head()
# Out:
# nan                                                                                                                                                                                                                                                                                                                                                                                                       920
# ['Air conditioning', 'Electrical side mirrors', 'Hill Holder', 'Power windows']                                                                                                                                                                                                                                                                                                                           216
# ['Air conditioning', 'Electrical side mirrors', 'Power windows']                                                                                                                                                                                                                                                                                                                                          134
# ['Air conditioning', 'Power windows']                                                                                                                                                                                                                                                                                                                                                                     130
# ['Air conditioning', 'Armrest', 'Automatic climate control', 'Cruise control', 'Electrical side mirrors', 'Leather steering wheel', 'Light sensor', 'Lumbar support', 'Multi-function steering wheel', 'Navigation system', 'Park Distance Control', 'Parking assist system sensors front', 'Parking assist system sensors rear', 'Power windows', 'Rain sensor', 'Seat heating', 'Start-stop system']    105
# Name: Comfort_Convenience, dtype: int64

# %%
df["Comfort_Convenience"] = [",".join(item) if type(item) == list else item for item in df["Comfort_Convenience"]]

# %%
df["Comfort_Convenience"].value_counts(dropna=False).head()
# Out:
# NaN                                                                                                                                                                                                                                                                                                                                                   920
# Air conditioning,Electrical side mirrors,Hill Holder,Power windows                                                                                                                                                                                                                                                                                    216
# Air conditioning,Electrical side mirrors,Power windows                                                                                                                                                                                                                                                                                                134
# Air conditioning,Power windows                                                                                                                                                                                                                                                                                                                        130
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system    105
# Name: Comfort_Convenience, dtype: int64

# %% [markdown]
# ## Entertainment_Media

# %%
df["Entertainment_Media"].astype('str').value_counts(dropna=False).head()
# Out:
# nan                                                                                               1374
# ['Bluetooth', 'Hands-free equipment', 'On-board computer', 'Radio', 'USB']                        1282
# ['Bluetooth', 'Hands-free equipment', 'MP3', 'On-board computer', 'Radio', 'USB']                  982
# ['Bluetooth', 'CD player', 'Hands-free equipment', 'MP3', 'On-board computer', 'Radio', 'USB']     783
# ['On-board computer', 'Radio']                                                                     487
# Name: Entertainment_Media, dtype: int64

# %%
df["Entertainment_Media"] = [",".join(item) if type(item) == list else item for item in df["Entertainment_Media"]]

# %%
df["Entertainment_Media"].value_counts(dropna=False).head()
# Out:
# NaN                                                                         1374
# Bluetooth,Hands-free equipment,On-board computer,Radio,USB                  1282
# Bluetooth,Hands-free equipment,MP3,On-board computer,Radio,USB               982
# Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio,USB     783
# On-board computer,Radio                                                      487
# Name: Entertainment_Media, dtype: int64

# %% [markdown]
# ## Extras

# %%
df["Extras"].astype('str').value_counts(dropna=False).head()
# Out:
# ['Alloy wheels']                                     3245
# nan                                                  2962
# ['Alloy wheels', 'Touch screen']                      697
# ['Alloy wheels', 'Voice Control']                     577
# ['Alloy wheels', 'Touch screen', 'Voice Control']     541
# Name: Extras, dtype: int64

# %%
df["Extras"] = [",".join(item) if type(item) == list else item for item in df["Extras"]]

# %%
df["Extras"].value_counts(dropna=False).head()
# Out:
# Alloy wheels                               3245
# NaN                                        2962
# Alloy wheels,Touch screen                   697
# Alloy wheels,Voice Control                  577
# Alloy wheels,Touch screen,Voice Control     541
# Name: Extras, dtype: int64

# %% [markdown]
# ## Safety_Security

# %%
df["Safety_Security"].astype('str').value_counts(dropna=False).head()
# Out:
# nan                                                                                                                                                                                                                                                                                                   982
# ['ABS', 'Central door lock', 'Daytime running lights', 'Driver-side airbag', 'Electronic stability control', 'Fog lights', 'Immobilizer', 'Isofix', 'Passenger-side airbag', 'Power steering', 'Side airbag', 'Tire pressure monitoring system', 'Traction control']                                  538
# ['ABS', 'Central door lock', 'Daytime running lights', 'Driver-side airbag', 'Electronic stability control', 'Immobilizer', 'Isofix', 'Passenger-side airbag', 'Power steering', 'Side airbag', 'Tire pressure monitoring system', 'Traction control']                                                480
# ['ABS', 'Central door lock', 'Daytime running lights', 'Driver-side airbag', 'Electronic stability control', 'Immobilizer', 'Isofix', 'Passenger-side airbag', 'Power steering', 'Side airbag', 'Tire pressure monitoring system', 'Traction control', 'Xenon headlights']                            275
# ['ABS', 'Central door lock', 'Daytime running lights', 'Driver-side airbag', 'Electronic stability control', 'Fog lights', 'Immobilizer', 'Isofix', 'LED Daytime Running Lights', 'Passenger-side airbag', 'Power steering', 'Side airbag', 'Tire pressure monitoring system', 'Traction control']    272
# Name: Safety_Security, dtype: int64

# %%
df["Safety_Security"] = [",".join(item) if type(item) == list else item for item in df["Safety_Security"]]

# %%
df["Safety_Security"].value_counts(dropna=False).head()
# Out:
# NaN                                                                                                                                                                                                                                                        982
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                               538
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                          480
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Xenon headlights                         275
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,LED Daytime Running Lights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control    272
# Name: Safety_Security, dtype: int64

# %% [markdown]
# **Now we can save our cleaned file as in csv format.**

# %%
df.shape
# Out:
# (15919, 32)

# %% [markdown]
# **We started with 54 columns at the beginning of the analysis, now we have 33 columns.**

# %%
df.head().T
# Out:
#                                                                      0  \
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            15770
# vat                                                     VAT deductible
# km                                                            56013.00
# Type                                                              Used
# Warranty                                                           NaN
# Cylinders                                                         3.00
# Fuel                                                            Diesel
# Comfort_Convenience  Air conditioning,Armrest,Automatic climate con...
# Entertainment_Media  Bluetooth,Hands-free equipment,On-board comput...
# Extras                  Alloy wheels,Catalytic Converter,Voice Control
# Safety_Security      ABS,Central door lock,Daytime running lights,D...
# Gears                                                              NaN
# age                                                               3.00
# Previous_Owners                                                   2.00
# hp_kW                                                            66.00
# Inspection_new                                                     Yes
# Paint_Type                                                    Metallic
# Upholstery_type                                                  Cloth
# Upholstery_color                                                 Black
# Nr_of_Doors                                                       5.00
# Nr_of_Seats                                                       5.00
# Gearing_Type                                                 Automatic
# Displacement_cc                                                1422.00
# Weight_kg                                                      1220.00
# Drive_chain                                                      front
# cons_comb                                                         3.80
# cons_city                                                         4.30
# cons_country                                                      3.50
# CO2_Emission                                                     99.00
# Emission_Class                                                  Euro 6
#
#                                                                      1  \
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            14500
# vat                                                   Price negotiable
# km                                                            80000.00
# Type                                                              Used
# Warranty                                                           NaN
# Cylinders                                                         4.00
# Fuel                                                           Benzine
# Comfort_Convenience  Air conditioning,Automatic climate control,Hil...
# Entertainment_Media  Bluetooth,Hands-free equipment,On-board comput...
# Extras               Alloy wheels,Sport seats,Sport suspension,Voic...
# Safety_Security      ABS,Central door lock,Central door lock with r...
# Gears                                                                7
# age                                                               2.00
# Previous_Owners                                                    NaN
# hp_kW                                                           141.00
# Inspection_new                                                     NaN
# Paint_Type                                                         NaN
# Upholstery_type                                                  Cloth
# Upholstery_color                                                  Grey
# Nr_of_Doors                                                       3.00
# Nr_of_Seats                                                       4.00
# Gearing_Type                                                 Automatic
# Displacement_cc                                                1798.00
# Weight_kg                                                      1255.00
# Drive_chain                                                      front
# cons_comb                                                         5.60
# cons_city                                                         7.10
# cons_country                                                      4.70
# CO2_Emission                                                    129.00
# Emission_Class                                                  Euro 6
#
#                                                                      2  \
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            14640
# vat                                                     VAT deductible
# km                                                            83450.00
# Type                                                              Used
# Warranty                                                           NaN
# Cylinders                                                          NaN
# Fuel                                                            Diesel
# Comfort_Convenience  Air conditioning,Cruise control,Electrical sid...
# Entertainment_Media                              MP3,On-board computer
# Extras                                      Alloy wheels,Voice Control
# Safety_Security      ABS,Central door lock,Daytime running lights,D...
# Gears                                                              NaN
# age                                                               3.00
# Previous_Owners                                                   1.00
# hp_kW                                                            85.00
# Inspection_new                                                     NaN
# Paint_Type                                                    Metallic
# Upholstery_type                                                  Cloth
# Upholstery_color                                                 Black
# Nr_of_Doors                                                       4.00
# Nr_of_Seats                                                       4.00
# Gearing_Type                                                 Automatic
# Displacement_cc                                                1598.00
# Weight_kg                                                          NaN
# Drive_chain                                                      front
# cons_comb                                                         3.80
# cons_city                                                         4.40
# cons_country                                                      3.40
# CO2_Emission                                                     99.00
# Emission_Class                                                  Euro 6
#
#                                                                      3  \
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            14500
# vat                                                               None
# km                                                            73000.00
# Type                                                              Used
# Warranty                                                           NaN
# Cylinders                                                         3.00
# Fuel                                                            Diesel
# Comfort_Convenience  Air suspension,Armrest,Auxiliary heating,Elect...
# Entertainment_Media  Bluetooth,CD player,Hands-free equipment,MP3,O...
# Extras                          Alloy wheels,Sport seats,Voice Control
# Safety_Security      ABS,Alarm system,Central door lock with remote...
# Gears                                                                6
# age                                                               3.00
# Previous_Owners                                                   1.00
# hp_kW                                                            66.00
# Inspection_new                                                     NaN
# Paint_Type                                                    Metallic
# Upholstery_type                                                    NaN
# Upholstery_color                                                   NaN
# Nr_of_Doors                                                       3.00
# Nr_of_Seats                                                       4.00
# Gearing_Type                                                 Automatic
# Displacement_cc                                                1422.00
# Weight_kg                                                      1195.00
# Drive_chain                                                        NaN
# cons_comb                                                         3.80
# cons_city                                                         4.30
# cons_country                                                      3.50
# CO2_Emission                                                     99.00
# Emission_Class                                                  Euro 6
#
#                                                                      4
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            16790
# vat                                                               None
# km                                                            16200.00
# Type                                                              Used
# Warranty                                                           NaN
# Cylinders                                                         3.00
# Fuel                                                            Diesel
# Comfort_Convenience  Air conditioning,Armrest,Automatic climate con...
# Entertainment_Media  Bluetooth,CD player,Hands-free equipment,MP3,O...
# Extras               Alloy wheels,Sport package,Sport suspension,Vo...
# Safety_Security      ABS,Central door lock,Driver-side airbag,Elect...
# Gears                                                              NaN
# age                                                               3.00
# Previous_Owners                                                   1.00
# hp_kW                                                            66.00
# Inspection_new                                                     Yes
# Paint_Type                                                    Metallic
# Upholstery_type                                                  Cloth
# Upholstery_color                                                 Black
# Nr_of_Doors                                                       5.00
# Nr_of_Seats                                                       5.00
# Gearing_Type                                                 Automatic
# Displacement_cc                                                1422.00
# Weight_kg                                                          NaN
# Drive_chain                                                      front
# cons_comb                                                         4.10
# cons_city                                                         4.60
# cons_country                                                      3.80
# CO2_Emission                                                    109.00
# Emission_Class                                                  Euro 6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 32 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   make_model           15919 non-null  object
#  1   body_type            15859 non-null  object
#  2   price                15919 non-null  int64
#  3   vat                  11406 non-null  object
#  4   km                   14895 non-null  float64
#  5   Type                 15917 non-null  object
#  6   Warranty             4853 non-null   float64
#  7   Cylinders            10239 non-null  float64
#  8   Fuel                 15919 non-null  object
#  9   Comfort_Convenience  14999 non-null  object
#  10  Entertainment_Media  14545 non-null  object
#  11  Extras               12957 non-null  object
#  12  Safety_Security      14937 non-null  object
#  13  Gears                11207 non-null  object
#  14  age                  14322 non-null  float64
#  15  Previous_Owners      9279 non-null   float64
#  16  hp_kW                15831 non-null  float64
#  17  Inspection_new       3932 non-null   object
#  18  Paint_Type           10147 non-null  object
#  19  Upholstery_type      11048 non-null  object
#  20  Upholstery_color     10841 non-null  object
#  21  Nr_of_Doors          15707 non-null  float64
#  22  Nr_of_Seats          14942 non-null  float64
#  23  Gearing_Type         15919 non-null  object
#  24  Displacement_cc      15423 non-null  float64
#  25  Weight_kg            8945 non-null   float64
#  26  Drive_chain          9061 non-null   object
#  27  cons_comb            13886 non-null  float64
#  28  cons_city            13483 non-null  float64
#  29  cons_country         13543 non-null  float64
#  30  CO2_Emission         13483 non-null  float64
#  31  Emission_Class       12291 non-null  object
# dtypes: float64(14), int64(1), object(17)
# memory usage: 2.9+ MB

# %%
df.to_csv("clean_scout.csv", index=False)

# %% [markdown]
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:150%; text-align:center; border-radius:10px 10px;">The End of Data Cleaning (Part - 01)</p>
#
# <a id="4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ____
